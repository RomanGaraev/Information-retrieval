# %% [markdown]
# In this lab you are going to implement a standard document processing pipeline and then build a simple search engine based on it:
# - starting from crawling documents,
# - then building an inverted index,
# - answering queries using this index,
# - and organizing it as a simple web server.
#
# Second part is devoted to spellchecking.
#
# # 1. [45] Building inverted index and answering queries
#
# ## 1.1. [5] Preprocessing
#
# First, we need a unified approach to documents preprocessing. Implement a class responsible for that. Complete the code for given functions (most of them are just one-liners) and make sure you pass the tests. Make use of `nltk` library or any other you know.

# %%
import nltk
nltk.download('punkt')

class Preprocessor:
    
    def __init__(self):
        self.stop_words = {'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he', 'in', 'is', 'it', 'its',
                      'of', 'on', 'that', 'the', 'to', 'was', 'were', 'will', 'with'}
        self.ps = nltk.stem.PorterStemmer()

    
    def tokenize(self, text):
        return nltk.word_tokenize(text)

    
    def stem(self, word, stemmer):
        return stemmer.stem(word)

    
    def is_apt_word(self, word):
        if word in self.stop_words or not word.isalpha() or len(word) == 1:
            return False
        return True

    
    def preprocess(self, text):
        preprocessed = self.tokenize(text.lower())
        preprocessed = [i for i in preprocessed if self.is_apt_word(i)]
        preprocessed = [self.stem(i, self.ps) for i in preprocessed if self.is_apt_word(i)]
        return preprocessed
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\demo8\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 1.1.1. Tests

# %%
prep = Preprocessor()
text = 'To be, or not to be, that is the question'

assert prep.tokenize(text) == ['To', 'be', ',', 'or', 'not', 'to', 'be', ',', 'that', 'is', 'the', 'question']
assert prep.stem('retrieval', prep.ps) == 'retriev'
assert prep.is_apt_word('qwerty123') is False
assert prep.preprocess(text) == ['or', 'not', 'question']

test = "I am writing super test test1, ha h a !"
print(prep.preprocess(test))
# Out:
# ['am', 'write', 'super', 'test', 'ha']

# %% [markdown]
# ## 1.2. [25] Crawling and Indexing
#
# ### 1.2.1. [5] Base classes
#
# Here are some base classes we will need for writing our indexer. The code from the first lab's solution is given, but note that you will need to change some of it, namely, the `parse` function (it is also possible to use your own implementation from the first homework, but make sure that it is correct). The reason is it always makes complete parsing, which we want to avoid when we only need links, for example, or a specific portion of text.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
import os


class Document:

    def __init__(self, url):
        self.url = url

    def download(self):
        try:
            response = requests.get(self.url)
            if response.status_code == 200:
                self.content = response.content
                return True
            else:
                self.content = ""
                return False
        except:
            self.content = ""
            return False

    def persist(self, path):
        with open(os.path.join(path, quote(self.url).replace('/', '_')), 'wb') as f:
            f.write(self.content)

# This class returns anchors only (content and filtering to articles will be latter)
class HtmlDocument(Document):
    def __init__(self, url):
        super().__init__(url)
        super().download()

    def normalize(self, href):
        if href is not None and href[:4] != 'http':
            href = urllib.parse.urljoin(self.url, href)
        return href

    def parse(self):
        
        def tag_visible(element):
            if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
                return False
            if isinstance(element, Comment):
                return False
            return True
            
        
        model = BeautifulSoup(self.content)
        
        self.anchors = []
        a = model.find_all('a')
        for anchor in a:
            href = self.normalize(anchor.get('href'))
            self.anchors.append(href)

# %%
doc = HtmlDocument("https://www.reuters.com/technology")
doc.download()
doc.parse()
print(doc.anchors)
# Out:
# ['https://www.reutersagency.com/en/media-center/welcome-to-the-new-reuters-com/', 'https://www.reuters.com/technology#main-content', 'https://www.reuters.com/', 'https://www.reuters.com/world/', 'https://www.reuters.com/business/', 'https://www.reuters.com/markets/', 'https://www.reuters.com/breakingviews/', 'https://www.reuters.com/signin/', 'https://www.reuters.com/technology/microsoft-says-group-behind-solarwinds-hack-now-targetting-government-agencies-2021-05-28/', 'https://www.reuters.com/technology/colonial-pipeline-says-experiencing-network-issues-2021-05-28/', 'https://www.reuters.com/technology/apple-delay-launch-podcast-subscription-service-until-june-2021-05-28/', 'https://www.reuters.com/technology/us-sec-charges-five-individuals-involved-crypto-lending-program-2021-05-28/', 'https://www.reuters.com/business/call-amazon-consider-blue-collar-director-wins-17-support-2021-05-28/', 'https://www.reuters.com/business/finance/bitcoin-slumps-8-it-heads-bruising-monthly-drop-2021-05-28/', 'https://www.reuters.com/technology/biden-budget-sets-aside-750-mln-solarwinds-response-2021-05-28/', 'https://www.reuters.com/business/autos-transportation/exclusive-wejo-go-public-deal-values-auto-data-startup-800-mln-sources-2021-05-28/', 'https://www.reuters.com/technology/us-senate-consider-sweeping-china-tech-bill-june-8-2021-05-28/', 'https://www.reuters.com/technology/software-provider-sprinklr-reveals-19-jump-quarterly-revenue-ipo-filing-2021-05-28/', 'https://www.reuters.com/technology/electric-vehicle-firm-rivian-could-seek-70-bln-valuation-ipo-bloomberg-news-2021-05-28/', 'https://www.reuters.com/technology/biden-seeks-11-jump-ftc-funding-big-tech-cases-loom-2021-05-28/', 'https://www.reuters.com/technology/tiktok-given-month-respond-claims-eu-consumer-rights-breaches-2021-05-28/', 'https://www.reuters.com/technology/meme-stocks-amc-gamestop-poised-end-strong-week-high-2021-05-28/', 'https://www.reuters.com/technology/logitech-ceo-says-chip-shortage-could-last-up-year-paper-2021-05-28/', 'https://www.reuters.com/technology/vietnam-coronavirus-outbreak-threatens-disrupt-tech-supply-chain-2021-05-28/', 'https://www.reuters.com/technology/russian-online-cinema-ivi-projects-ambitious-investment-with-new-cash-2021-05-28/', 'https://www.reuters.com/technology/swiss-cabinet-blames-intelligence-community-crypto-ag-affair-2021-05-28/', 'https://www.reuters.com/world/us/sweeping-bill-counter-china-wins-enough-support-advance-us-senate-2021-05-27/', 'https://www.reuters.com/business/autos-transportation/nissan-plans-work-stoppages-mexico-june-due-chip-shortage-2021-05-28/', 'https://www.reuters.com/world/', 'https://www.reuters.com/business/', 'https://www.reuters.com/markets/', 'https://www.reuters.com/breakingviews/', 'https://www.reuters.com/technology/', 'https://www.reuters.com/investigates/', 'https://www.reuters.com/lifestyle/', 'https://www.reutersagency.com/en/about/about-us/', 'https://www.thomsonreuters.com/en/careers.html', 'https://www.reutersagency.com/en/?utm_source=website&utm_medium=reuters&utm_campaign=site-referral&utm_content=us&utm_term=0', 'https://www.reutersagency.com/en/about/about-us/brand-attribution-guidelines/', 'https://www.reutersagency.com/en/about/leadership-team/', 'https://www.reuters.com/fact-check/', 'https://static.reuters.com/resources/media/editorial/20210405/DiversityReportApril2021.pdf', 'https://www.reuters.com/tools/mobile/us', 'https://newslink.reuters.com/join/subscribe', 'https://www.twitter.com/Reuters', 'https://www.facebook.com/Reuters', 'https://www.instagram.com/Reuters', 'https://www.youtube.com/user/ReutersVideo', 'https://www.linkedin.com/company/10256858/', 'https://legal.thomsonreuters.com/en/products/westlaw', 'https://tax.thomsonreuters.com/en/onesource', 'https://tax.thomsonreuters.com/en/checkpoint', 'https://www.refinitiv.com/en/products/eikon-trading-software', 'https://www.refinitiv.com/en/products/refinitiv-data-platform ', 'https://www.refinitiv.com/en/products/world-check ...

# %% [markdown]
# ### 1.2.2. [15] Main class
#
# The main indexer logic is here. We organize it as a crawler generator that adds certain visited pages to inverted index and saves them on disk.
#
# - `crawl_generator_for_index` method crawles the given website doing BFS, starting from `source` within given `depth`. Considers only inner pages (of a form https://www.reuters.com/...) for visiting. To speed up, doesn't consider for visiting pages with content type other than html: '.pdf', '.mp3', '.avi', '.mp4', '.txt'. If encounters an article page (of a form https://www.reuters.com/article/...), saves its content in a file in `collection_path` folder and populates the inverted index calling `index_doc` method. When done, saves on disk three resulting dictionaries:
#     - `doc_urls`, `doc_id:url`
#     - `index`, `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#     - `doc_lengths`, `doc_id:doc_length`
#
#     `limit` parameter is given for testing - if not `None`, break the loop when number of saved articles exceeds the `limit` and return without writing dictionaries to disk.
#
#
# - `index_doc` method parses and preprocesses the content of a `doc` and adds it to the inverted index. Also keeps track of document lengths in a `doc_lengths` dictionary.
#
#
# **Extra task \* (no penalty to skip)** In real industrial systems a crawler would pass the links to the dedicated service that would load their contents in a bunch of parallel threads. Implement such a service - get urls as inputs, load page contents in parallel and return filenames on disk, which are then processed by indexer.

# %%
# Support class for getting urls of articles only from https://www.reuters.com/
class ArticleCrawler:
    def __init__(self, limit=None):
      # Collecting visited url
      self.visited = []
      # Set is cooler than Queue, because it automatically checks duplicates
      self.articles = set()
      # Max of articles
      self.limit = limit or 100000000000000

    def check(self, url):
        # Correct URL & Didn't see before & from https://www.reuters.com/... & just html
        return  (url is not None) and \
                (url not in self.visited) and \
                (self.root in url) and \
                (url[-4:] not in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'))

    # Find all refs and add them to the set
    def crawling(self, url, queue):
        if url in self.visited:
            return
        self.visited.append(url)
        doc = HtmlDocument(url)
        doc.parse()
        urls = doc.anchors
        # Add only correct refs
        for i in urls:
            if self.check(i):
                # refs from queue would be checked latter
                queue.add(i)
                # If this is an article, add  also to the set of articles
                if "/article/" in i:
                    self.articles.add(i)

    def get_urls(self, source, depth = 1):
        # https://www.reuters.com
        self.root = source.split(".com/")[0]
        # Refs from source
        old_set = set()
        self.crawling(source, old_set)
        # BFS
        for i in range(depth - 1):
            # New level of refs tree
            new_set = set()
            for url in old_set:
                self.crawling(url, new_set)
                # If self.crawling found enough articles
                if len(self.articles) >= self.limit:
                    return list(self.articles)[:self.limit]
            old_set = new_set
            print("Depth", i, " is done. Found ", len(self.articles))
        # If limit=None (or greater than count of articles), return the all findings
        return list(self.articles)

# %%
from collections import Counter
import pickle
import os

class Indexer:

    def __init__(self):      
        # dictionaries to populate
        self.doc_urls = {}        
        self.index = {}
        self.doc_lengths = {}
        # preprocessor
        self.prep = Preprocessor()

    def crawl_generator_for_index(self, source, depth, collection_path="collection", limit=None):        
        # Articles urls
        urls = ArticleCrawler(limit).get_urls(source, depth)
        # Get the content from articles
        for i in range(len(urls)):
            self.doc_urls[i] = urls[i]
            # Head & body of html
            content = BeautifulSoup(str(requests.get(urls[i], allow_redirects=False).content))
            head = content.findAll('h1')
            doc = content.findAll('article')
            art_text = ""
            for j in doc:
                art_text += j.text
            for j in head:
                art_text += " " + j.text
            self.index_doc(art_text, i)
        with open(os.path.join(collection_path, 'doc_urls.p'), 'wb') as fp:
            pickle.dump(self.doc_urls, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(collection_path, 'inverted_index.p'), 'wb') as fp:
            pickle.dump(self.index, fp, protocol=pickle.HIGHEST_PROTOCOL)
        with open(os.path.join(collection_path, 'doc_lengths.p'), 'wb') as fp:
            pickle.dump(self.doc_lengths, fp, protocol=pickle.HIGHEST_PROTOCOL)
        # Difference from template: list of urls instead of HtmlDocument,
        # because it is parsed in another place
        return self.doc_urls.values()

    def index_doc(self, doc, doc_id):
        preproc = self.prep.preprocess(doc)
        count = Counter()
        for word in preproc:
            count[word] += 1
        for word in count:
            if len(self.index.setdefault(word, [])) == 0:
                self.index.setdefault(word, []).append(count[word])
            else:
                self.index.setdefault(word, [])[0] +=count[word]
            self.index.setdefault(word, []).append((doc_id, count[word]))
        self.doc_lengths[doc_id] = len(preproc)

# %% [markdown]
# ### 1.2.3. Tests

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/technology", 2, "test_collection", 5):
    print(k, c)
    k+=1

assert type(indexer.index) is dict
assert type(indexer.index['reuter']) is list
assert type(indexer.index['reuter'][0]) is int
assert type(indexer.index['reuter'][1]) is tuple
# Out:
# 1 https://www.reuters.com/article/factcheck-nasa-zodiac/fact-check-false-posts-about-nasa-changing-the-zodiac-resurface-idUSL2N2NF2AW
# 2 https://www.reuters.com/article/factcheck-deer-man/fact-check-story-of-man-who-self-identifies-as-a-deer-stems-from-satire-idUSL2N2NE2BN
# 3 https://www.reuters.com/article/factcheck-microchip-vaccine/fact-check-pictured-microchip-is-unrelated-to-covid-19-vaccine-idUSL2N2NF0XQ
# 4 https://www.reuters.com/article/factcheck-chelsea-clinton/fact-check-fabricated-chelsea-clinton-tweet-about-racial-rehab-idUSL2N2NE2LR
# 5 https://www.reuters.com/article/factcheck-trojan-preowned/fact-check-trojan-is-not-selling-pre-owned-condoms-idUSL2N2NF296

# %% [markdown]
# ### 1.2.4. Building an index

# %%
# Take some time...
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/", 3, "docs_collection"):
    print(k, c)
    k+=1
# Out:
# Depth 0  is done. Found  51
# Depth 1  is done. Found  856
# 1 https://www.reuters.com/article/factcheck-maskless-dems/fact-check-video-of-maskless-democrats-taken-after-cdcs-latest-guidance-idUSL2N2ND1RD
# 2 https://www.reuters.com/article/us-usa-biden-budget/money-is-cheap-lets-spend-it-white-house-6-trillion-budget-message-idUSKCN2D9105#main-content
# 3 https://www.reuters.com/article/jd-logistics-listing/update-4-jd-logistics-shares-lose-steam-to-close-3-3-higher-idUSL2N2NF02L
# 4 https://www.reuters.com/article/us-china-usa-trade/china-u-s-can-find-common-ground-on-tariff-exclusions-chinese-think-tank-says-idUSKCN2DA06J
# 5 https://www.reuters.com/article/us-weir-group-divestiture-caterpillar/weir-group-to-sell-oil-gas-division-to-caterpillar-shares-surge-idUSKBN26Q0O6
# 6 https://www.reuters.com/article/us-usa-military-warren/sen-warren-seeks-investigation-of-landlord-at-u-s-air-force-base-idUSKCN1TS1YY
# 7 https://www.reuters.com/article/rivian-ipo/update-1-electric-vehicle-firm-rivian-could-seek-70-bln-valuation-in-ipo-bloomberg-news-idUSL3N2NF3V9#main-content
# 8 https://www.reuters.com/article/us-usa-housing-reform/u-s-military-intensifies-scrutiny-on-housing-issues-ultimatum-on-health-hazards-idUSKBN1WH2MK
# 9 https://www.reuters.com/article/brief-ryanair-to-ground-majority-of-airc/brief-ryanair-to-ground-majority-of-aircraft-fleet-across-europe-over-next-7-10-days-idUSFWN2B90KT
# 10 https://www.reuters.com/article/us-global-markets-themes/take-five-retail-pmis-and-a-timely-tantrum-anniversary-idUSKBN2CV0NF
# 11 https://www.reuters.com/article/health-coronavirus-bofaml/bank-of-america-to-give-u-s-staff-paid-time-off-to-get-vaccinated-bloomberg-news-idUSL4N2KW4ZF
# 12 https://www.reuters.com/article/caterpillar-results/caterpillar-earnings-dive-as-economy-woes-deter-equipment-purchases-idUSKBN27C2BC
# 13 https://www.reuters.com/article/us-usa-jails-westvirginia/west-virginia-lawmakers-push-jail-reform-in-response-to-reuters-data-on-inmate-deaths-idUSKBN28R36Z
# 14 https://www.reuters.com/article/us-citigroup-m-a-asia-exclusive/exclusive-dbs-stanchart-weigh-bids-as-citi-retreats-from-asia-consumer-business-sources-idUSKBN2C70SV
# 15 https://www.reuters.com/article/canada-forex/canada-fx-debt-canadian-dollar-ends-weekly-win-streak-as-u-s-inflation-jumps-idUSL2N2NF2ED
# 16 https://www.reuters.com/article/uk-global-forex/dollar-heads-for-third-weekly-gain-as-payrolls-data-looms-idUSKBN2BP0BB
# 17 https://www.reuters.com/article/us-usa-budget-interior/u-s-oil-and-gas-leasing-review-to-be-released-in-early-summer-official-idUSKCN2D9299
# 18 https://www.reuters.com/article/caterpillar-results/caterpillar-quarterly-earnings-plunge-46-on-coronavirus-fallout-idUSL3N2CG0K3
# 19 https://www.reuters.com/article/global-markets/global-markets-stocks-push-for-record-high-on-6-trillion-u-s-spending-hopes-idUSL5N2NF20E#main-content
# 20 https://www.reuters.com/article/uk-britain-sterling/sterling-drops-as-new-uk-lockdown-measures-outweigh-brexit-deal-relief-idUSKBN2990VR
# 21 https://www.reuters.com/article/us-citi-hong-kong/citi-on-hong-kong-hiring-spree-in-effort-to-triple-client-numbers-idUSKBN2C317P
# 22 https://www.reuters.com/article/uk-britain-sterling/pound-extends-gains-on-new-post-brexit-transition-time-for-swaps-trading-idUSKBN2950XS
# 23 https://www.reuters.com/article/brf-results/update-1-brazils-brf-posts-first-quarter-profit-below-analysts-estimates-idUSL1N2MZ3DE
# 24 https://www.reuters.com/article/us-jp-morgan-ceo/working-from-home-doesnt-work-for-those-who-want-to-hustle-jpmorgan-ceo-idUSKBN2CL1HQ
# 25 https://www.reuters.com/article/us-morgan-stanley-moves/morgan-stanley-ceo-shakes-up-leadership-in-search-for-successor-idUSKCN2D11DC
# 26 https://www.reuters.com/article/us-caterpillar-services-technology-focus/caterpillar-bets-on-self-driving-machines-impervious-to-pandemics-idUSKBN26X1ET
# 27 https://www.reuters.com/article/factcheck-shakespeare-vaccine/fact-check-the-first-man-to-receive-pfizer-biontech-vaccine-william-shakespeare-died-from-a-stroke-not-the-jab-idUSL2N2NF1HP
# 28 https://www.reuters.com/article/usa-stocks/us-stocks-snapshot-sp-500-dow-hit-record-highs-after-bumper-earnings-from-big-banks-idUSL4N2M934H
# 29 https://www.reuters.com/article/health-coronavirus-jp-morgan/jpmorgan-tells-vaccinated-employees-no-mask-required-at-work-idUSL2N2N526V
# 30 https://www.reuters.com/article/jbs-sharecancel/brazils-jbs-cancels-all-shares-held-in-treasury-idUSS0N2HJ01B
# 31 https://www.reuters.com/article/us-equinor-nigeria-court/equinor-says-it-wins-nigerian-case-over-agbami-oilfield-funds-idUSKBN2A51RC
# 32 https://www.reuters.com/article/us-socialmedia-israel-facebook-twitter/israeli-media-urges-facebook-twitter-to-act-on-incitement-against-reporters-idUSKCN2D623O
# 33 https://www.reuters.com/article/us-refinery-operations-total-portarthur/total-port-arthur-texas-refinery-restarting-hydrotreater-coker-sources-idUSKBN266224
# 34 https://www.reuters.com/article/us-china-morgan-stanley/morgan-stanley-nears-full-ownership-of-china-ventures-with-stake-buys-idUSKCN2D90VQ
# 35 https://www.reuters.com/article/us-usa-military-budget/u-s-senate-committee-proposes-301-million-for-military-housing-reform-plan-idUSKCN1ST2MX
# 36 https://www.reuters.com/article/us-britain-economy-trade/the-covid-brexit-cocktail-uk-lost-market-share-in-u-s-germany-and-china-report-idUSKBN2B0001
# 37 https://www.reuters.com/article/us-facebook-germany/facebook-german-publisher-axel-springer-strike-global-cooperation-deal-idUSKCN2CY1I7
# 38 https://www.reuters.com/article/total-results/rpt-total-back-to-pre-pandemic-profit-levels-as-oil-prices-rise-idUSL8N2MM2BZ
# 39 https://www.reuters.com/article/amazon-investors-workers/update-1-amazon-pressed-for-racial-equity-review-after-strong-vote-tally-idUSL2N2NF2TI#main-content
# 40 https://www.reuters.com/article/us-goldman-sachs-shareholder-breakingvie/goldman-diversity-double-speak-gets-investor-slap-idUSKBN2CG2HR
# 41 https://www.reuters.com/article/us-usa-lead-reform/u-s-cities-move-to-curb-lead-poisoning-following-reuters-report-idUSKBN1531P7
# 42 https://www.reuters.com/article/us-jpmorgan-financing-emerging/jpmorgan-development-arm-eyes-vaccine-supply-chain-gender-focused-lending-idUSKBN2CH1DN
# 43 https://www.reuters.com/article/us-boeing-737max-ryanair/ryanair-sees-737-max-return-in-u-s-in-next-month-or-so-idUSKBN26U0UC
# 44 https://www.reuters.com/article/refinery-operations-marathon-st-paul-par/marathon-and-teamsters-at-an-impasse-at-st-paul-park-refinery-letter-to-union-idUSL1N2MT208
# 45 https://www.reuters.com/article/twitter-ark/cathie-woods-investment-firm-buys-71-mln-worth-of-twitter-shares-on-dip-bloomberg-news-idUSL4N2MQ2MU
# 46 https://www.reuters.com/article/us-ryanair-italy/italys-aviation-authority-meets-ryanair-over-covid-19-compliance-dispute-idUSKBN2682SD
# 47 https://www.reuters.com/article/us-climate-new-york-oil/new-york-city-sues-exxon-bp-shell-in-state-court-over-climate-change-idUSKBN2C92BD
# 48 https://www.reuters.com/article/turkey-currency/update-4-turkish-lira-hits-record-low-in-latest-mark-of-vulnerability-idUSL5N2NF1MU#main-content
# 49 https://www.reuters.com/article/us-britain-g7-trade/g7-criticises-nations-who-undermine-global-trade-in-rallying-cry-for-reform-idUSKCN2D91ZC
# 50 https://www.reuters.com/article/us-britain-retail-rents/british-retail-faces-tsunami-of-closures-without-rent-help-idUSKCN2DA0IO
# 51 https://www.reuters.com/article/us-europe-stocks/european-stocks-end-below-record-high-as-mining-losses-offset-tech-rally-idUSKCN2D60O5
# 52 https://www.reuters.com/article/us-global-markets-themes-graphic/take-five-spring-in-the-step-idUSKBN2BO55G
# 53 https://www.reuters.com/article/us-usa-stocks/wall-street-ends-mixed-despite-bumper-big-bank-earnings-idUSKBN2C11AS
# 54 https://www.reuters.com/article/us-global-forex/euro-beats-yen-sterling-as-brexit-u-s-stimulus-boost-risk-appetite-idUSKBN292059
# 55 https://www.reuters.com/article/us-venezuela-russia-oil-specialreport/special-report-vladimirs-venezuela-leveraging-loans-to-caracas-moscow-snaps-up-oil-assets-idUSKBN1AR14U
# 56 https://www.reuters.com/article/us-grains-supply-special-report/special-report-drowning-in-grain-how-big-ag-sowed-seeds-of-a-profit-slashing-glut-idUSKCN1C21AR
# 57 https://www.reuters.com/article/us-refinery-operations-total-portarthur/totals-port-arthur-texas-reformer-returns-to-normal-operation-sources-idUSKBN22Y323
# 58 https://www.reuters.com/article/us-refinery-operations-marathon-galvesto/marathon-galveston-bay-refinery-in-texas-restarts-gasoline-unit-reformer-sources-idUSKBN2BW29Y
# 59 https://www.reuters.com/article/us-natl-bk-canada-results/canadas-national-bank-beats-profit-forecasts-with-lower-provisions-lending-growth-idUSKCN2D913S
# 60 https://www.reuters.com/article/usa-sec-bitconnect/u-s-sec-charges-five-individuals-involved-in-crypto-lending-program-idUSFWN2NF0Z1
# 61 https://www.reuters.com/article/us-myanmar-rohingya-eu-exclusive-idUSKCN1MD28E
# 62 https://www.reuters.com/article/us-health-coronavirus-britain-airlines/uk-airlines-call-for-tax-break-to-help-boost-demand-idUSKCN24L1A2
# 63 https://www.reuters.com/article/legal-us-citigroup-revlon-lawsuit/judge-denies-citigroup-a-longer-freeze-on-botched-revlon-transfer-idUSKBN2CT2FR
# 64 https://www.reuters.com/article/us-health-who-congress-exclusive/exclusive-congressional-committee-questions-operation-of-who-cancer-agency-idUSKBN1D15TU
# 65 https://www.reuters.com/article/eni-spinoff-adviser/eni-working-with-goldman-sachs-mediobanca-on-retail-renewable-spinoff-sources-idUSKBN2CV251
# 66 https://www.reuters.com/article/exxon-mobil-agm-blackrock/exclusive-blackrock-backs-dissidents-nominees-in-rebuke-to-exxon-sources-idUSL2N2NC1U3
# 67 https://www.reuters.com/article/us-fintech-cryptocurrency-bitcoin/bitcoin-falls-5-2-to-33849-ether-down-6-3-idUSKCN2DA0F2
# 68 https://www.reuters.com/article/us-ford-motor-sk-innovation-batteries/ford-motor-sk-innovation-announce-ev-battery-joint-venture-in-n-america-idUSKCN2D11KH
# 69 https://www.reuters.com/article/usa-biden-budget-treasury/bidens-tax-hike-plans-would-raise-2-4-trillion-after-energy-child-credits-treasury-idUSL2N2NF22G
# 70 https://www.reuters.com/article/india-stocks/indias-blue-chip-nifty-50-ends-at-record-high-idUSL3N2NF1D6
# 71 https://www.reuters.com/article/pemex-shell-deer-park-shell/moodys-downgrades-deer-park-after-pemex-acquires-houston-refinery-idUSL2N2NF080
# 72 https://www.reuters.com/article/us-exxon-mobil-agm-activists/new-hedge-funds-bask-in-exxons-climate-spotlight-idUSKCN2D7302
# 73 https://www.reuters.com/article/global-markets-themes/graphic-take-five-a-looming-labour-crunch-idUSL5N2NE669#main-content
# 74 https://www.reuters.com/article/uk-shell-netherlands-court-shrink/dutch-court-ruling-to-lead-to-shells-shrinking-analysts-idUSKCN2D82A3
# 75 https://www.reuters.com/article/us-usa-military-survey/military-survey-finds-deep-dissatisfaction-with-family-housing-on-u-s-bases-idUSKCN1Q21GR
# 76 https://www.reuters.com/article/us-twitter-results-breakingviews/twitter-can-learn-to-love-the-flock-it-has-idUSKBN2CH08H
# 77 https://www.reuters.com/article/g7-summit-economy/uk-calls-for-progress-on-climate-finance-after-g7-meeting-idUSS8N2L3024
# 78 https://www.reuters.com/article/us-usa-military-bill/u-s-congress-approves-sweeping-military-housing-overhaul-idUSKBN1YL2C5?il=0
# 79 https://www.reuters.com/article/us-foxconn-electric/foxconn-eyes-evs-for-troubled-wisconsin-plant-may-go-with-mexico-idUSKBN2B8191
# 80 https://www.reuters.com/article/southkorea-markets-midday/s-korea-stocks-fall-for-fourth-day-tracking-choppy-wall-st-idUSL4N2LM0AR
# 81 https://www.reuters.com/article/us-europe-stocks/european-stocks-rebound-after-upbeat-earnings-chip-ma-activity-idUSKCN2D10NI
# 82 https://www.reuters.com/article/exxon-mobil-agm-t-rowe-price-grp/t-rowe-price-backed-activist-nominees-in-exxon-board-contest-idUSL2N2NF276
# 83 https://www.reuters.com/article/unicredit-ceo-pay/corrected-update-2-unicredits-top-investor-blackrock-voted-against-ceo-pay-idUSL1N2N02FO
# 84 https://www.reuters.com/article/us-people-lewinsky/monica-lewinsky-revisits-humiliation-of-clinton-affair-in-interview-idUSKBN0F653W20140701
# 85 https://www.reuters.com/article/legal-us-facebook-privacy/irish-data-regulator-resumes-facebook-data-transfer-probe-idUSKCN2D22HE
# 86 https://www.reuters.com/article/us-hongkong-security-law-analysis-idUSKBN22Z0MU
# 87 https://www.reuters.com/article/russia-twitter/update-2-russia-partially-halts-punitive-twitter-slowdown-warns-other-tech-platforms-idUSL2N2N4194
# 88 https://www.reuters.com/article/us-britain-fintech/britain-to-offer-fast-track-visas-to-bolster-fintechs-after-brexit-idUSKBN2AQ0OV
# 89 https://www.reuters.com/article/us-exxon-mobil-agm-board-insight/the-little-engine-that-could-and-the-oil-giant-that-couldnt-idUSKCN2D80F3
# 90 https://www.reuters.com/article/us-petro-rio-total/petro-rio-buys-stake-in-brazil-oil-block-from-total-idUSKBN2AW2ZE
# 91 https://www.reuters.com/article/brf-production-int/brazils-brf-to-halt-halal-chicken-plant-for-modernization-work-idUSKBN2762TX
# 92 https://www.reuters.com/article/japan-stocks-close/japanese-shares-end-higher-on-wall-street-gains-stable-u-s-rates-idUSL3N2N81JI
# 93 https://www.reuters.com/article/us-usa-court-qualified-immunity/supreme-court-rejects-cases-over-qualified-immunity-for-police-idUSKBN23M1YH
# 94 https://www.reuters.com/article/us-usa-products-colonial-pipeline-valero/u-s-refiner-valero-granted-jones-act-waiver-after-colonial-outage-sources-idUSKBN2CU26Q
# 95 https://www.reuters.com/article/blackrock-oil-votes/blackrock-goes-against-bp-board-in-climate-resolution-vote-idUSL5N2NF4WK
# 96 https://www.reuters.com/article/us-m-a-pet-food-general-mills/faegre-hogan-lovells-steer-general-mills-1-2-billion-kibble-deal-with-tyson-idUSKBN2CV2GW
# 97 https://www.reuters.com/article/usa-bonds/treasuries-u-s-yields-fall-on-month-end-impact-investors-shrug-off-inflation-rise-idUSL2N2NF1ZC
# 98 https://www.reuters.com/article/us-goldman-sachs-director-harris/goldmans-new-director-makes-its-board-almost-half-female-idUSKCN2D51EH
# 99 https://www.reuters.com/article/us-usa-military-response/u-s-military-advances-sprawling-mission-to-quell-housing-safety-scandal-idUSKCN1RN2J5
# 100 https://www.reuters.com/article/phillips-66-biofuels/phillips-66-to-reconfigure-california-refinery-for-renewable-fuels-idUSL4N2FE3MY
# 101 https://www.reuters.com/article/us-usa-biden-budget/money-is-cheap-lets-spend-it-white-house-6-trillion-budget-message-idUSKCN2D9105
# 102 https://www.reuters.com/article/us-cosco-ship-hold-greece-piraeus/chinas-cosco-hopes-for-greek-deal-on-piraeus-despite-delay-official-idUSKCN2D91H7
# 103 https://www.reuters.com/article/us-health-coronavirus/who-urges-world-not-to-halt-vaccinations-as-astrazeneca-shot-divides-europe-idUSKBN2B71PU
# 104 https://www.reuters.com/article/us-foxconn-results/foxconn-sees-q2-surge-after-profit-leaps-on-covid-19-work-from-home-boom-idUSKBN2CV0GM
# 105 https://www.reuters.com/article/uk-usa-immigration-border-idUKKBN2B908V
# 106 https://www.reuters.com/article/total-apache-suriname/apache-total-make-third-oil-discovery-offshore-suriname-idUSL3N2F04ZB
# 107 https://www.reuters.com/article/usa-stocks/us-stocks-wall-street-shakes-off-inflation-rise-and-closes-higher-idUSL2N2NF2OS
# 108 https://www.reuters.com/article/employment-tyson/doj-blue-states-say-tyson-wrongful-death-lawsuits-belong-in-state-court-idUSL1N2M701Q
# 109 https://www.reuters.com/article/us-twitter-news/twitter-acquires-news-startup-scroll-in-push-for-subscriptions-idUSKBN2CL1BB
# 110 https://www.reuters.com/article/us-norway-oil/union-threatens-strike-action-at-norways-onshore-oil-gas-facilities-if-wage-talks-fail-idUSKBN29K0XM
# 111 https://www.reuters.com/article/us-semiconductor-shortage-packaging-focu/bidens-chip-dreams-face-reality-check-of-supply-chain-complexity-idUSKBN2C01AL
# 112 https://www.reuters.com/article/us-hongkong-politics-extradition-judges/exclusive-hong-kong-judges-see-risks-in-proposed-extradition-changes-idUSKCN1SZ09U
# 113 https://www.reuters.com/article/china-icbc-goldman-sachs/china-approves-goldman-sachs-icbc-joint-wealth-management-venture-idUSFWN2NB0YZ
# 114 https://www.reuters.com/article/marathon-ptrlum-ma-seveni-hldgs-ftc/corrected-seven-i-holdings-co-marathon-petroleum-deal-closed-at-their-own-risk-officials-idUSL1N2N126T
# 115 https://www.reuters.com/article/brf-outlook/update-5-brazils-brf-shares-soar-after-bold-10-year-plan-idUSL1N2IO0ZK
# 116 https://www.reuters.com/article/belarus-politics-russia/update-2-russia-confirms-second-loan-for-belarus-raises-issue-of-detained-citizen-idUSL2N2NG0AC
# 117 https://www.reuters.com/article/us-global-oil/oil-jumps-over-3-as-fears-of-iranian-exports-ease-idUSKCN2D503J
# 118 https://www.reuters.com/article/us-refinery-marathon/union-urges-shareholders-to-vote-against-marathon-exec-pay-letter-idUSKBN2BL1KA
# 119 https://www.reuters.com/article/uk-britain-sterling-eu/pound-rises-above-1-35-on-brexit-trade-deal-expectations-idUSKBN28X1QQ
# 120 https://www.reuters.com/article/us-bp-divestiture-alaska/hilcorps-harvest-alaska-unit-completes-bp-alaska-acquisition-idUSKBN28S2Z6
# 121 https://www.reuters.com/article/global-forex-int/dollar-up-from-2018-lows-on-economic-hopes-euro-profit-taking-idUSKBN29C04W
# 122 https://www.reuters.com/article/equinor-lng/update-3-equinor-lng-plant-broke-rules-ahead-of-2020-fire-watchdog-says-idUSL8N2MF2DS
# 123 https://www.reuters.com/article/us-bitcoin-tezos-battles/tezos-leaders-ask-for-patience-over-dispute-on-cybercurrency-project-idUSKBN1CT2LZ
# 124 https://www.reuters.com/article/uk-scotland-independence-morganstanley/banks-see-15-35-chance-of-scottish-independence-as-key-vote-nears-idUSKBN2CF0TK
# 125 https://www.reuters.com/article/us-health-coronavirus-britain-jp-morgan/jpmorgan-to-bring-all-staff-back-to-office-in-england-memo-idUSKBN2CS1JB
# 126 https://www.reuters.com/article/us-hongkong-protests-soe-exclusive/exclusive-china-prods-state-firms-to-boost-investment-in-crisis-hit-hong-kong-idUSKCN1VY08C
# 127 https://www.reuters.com/article/us-citigroup-hiring/citi-sets-sights-on-1000-wealth-hirings-in-hong-kong-idUSKBN2CU0LI
# 128 https://www.reuters.com/article/us-health-coronavirus-meat/after-covid-19-outbreak-brf-plant-in-southern-brazil-cleared-to-resume-exports-to-china-idUSKBN28A2JZ
# 129 https://www.reuters.com/article/us-health-coronavirus-britain-vaccine-sp-idUKKBN28Y0XU
# 130 https://www.reuters.com/article/us-usa-courts-secrecy-congress/house-leader-to-back-bill-limiting-court-secrecy-idUSKBN1WB32P
# 131 https://www.reuters.com/article/uk-bp-wind-auction/bp-seeking-to-build-wind-farms-off-scotland-the-times-idUSKBN2CJ0MP
# 132 https://www.reuters.com/article/us-canada-politics-lawmaker/canadian-lawmaker-caught-urinating-on-virtual-video-stream-after-naked-gaffe-idUSKCN2D924J
# 133 https://www.reuters.com/article/brief-eicher-motors-march-total-motorcyc/brief-eicher-motors-march-total-motorcycles-sales-fall-to-35814-units-idUSFWN2BP1C1
# 134 https://www.reuters.com/article/us-bp-emissions/bp-reports-10-drop-in-overall-emissions-in-2020-idUSKBN2BE2DN
# 135 https://www.reuters.com/article/global-markets/global-markets-equities-dollar-gain-on-rising-u-s-inflation-idUSL2N2NF2PD#main-content
# 136 https://www.reuters.com/article/us-chile-copper-strike/strike-at-bhps-chile-copper-mine-continues-union-opposes-substitute-workers-idUSKCN2D92CM
# 137 https://www.reuters.com/article/us-bank-of-america-esg/bank-of-america-to-deploy-1-trillion-for-sustainable-finance-by-2030-idUSKBN2BV29W
# 138 https://www.reuters.com/article/us-ceraweek-colombia-isabritain-eu-audit/ecopetrols-purchase-of-isa-shares-could-provide-income-stability-regulator-idUSKBN2AT2XJ
# 139 https://www.reuters.com/article/us-climate-change-investors/top-u-s-fund-leader-wants-voluntary-climate-disclosure-rules-idUSKBN2CN21X
# 140 https://www.reuters.com/article/jpmorgan-dimon-pay/proxy-adviser-iss-backs-pay-plan-for-jpmorgan-ceo-dimon-idUSL1N2MS3AF
# 141 https://www.reuters.com/article/valero-energy-results/refiner-valeros-quarterly-loss-narrows-as-fuel-demand-recovers-idUSL4N2K3384
# 142 https://www.reuters.com/article/us-climate-change-litigation-analysis/analysis-big-oil-may-get-more-climate-lawsuits-after-shell-ruling-lawyers-activists-idUSKCN2D90TK
# 143 https://www.reuters.com/article/us-brf-outlook/brazils-brf-flags-challenges-of-coronavirus-testing-for-meat-guarantees-safety-idUSKCN25928U
# 144 https://www.reuters.com/article/us-total-agm/were-totalenergies-french-oil-major-gets-green-rebrand-idUSKCN2D90U3
# 145 https://www.reuters.com/article/us-europe-stocks/european-shares-hit-record-high-on-airbus-boost-bayer-hurt-by-roundup-ruling-idUSKCN2D80QW
# 146 https://www.reuters.com/article/legal-us-wejo-m-a-spac/wejo-to-go-public-deal-values-auto-data-startup-at-800-million-idUSKCN2D92FY
# 147 https://www.reuters.com/article/norway-oil-equinor/update-1-equinor-makes-oil-discovery-near-norways-troll-field-idUSL1N2KB0JO
# 148 https://www.reuters.com/article/us-wejo-m-a-spac-exclusive/wejo-to-go-public-deal-values-auto-data-startup-at-800-million-idUSKCN2D92CP
# 149 https://www.reuters.com/article/us-china-derivatives-aluminium-climate-c/chinas-non-ferrous-sector-carbon-emissions-to-peak-after-2025-assoc-idUSKCN2D90C5
# 150 https://www.reuters.com/article/us-norway-oil-equinor/equinor-makes-oil-discovery-near-norways-troll-field-idUSKBN2A50R7
# 151 https://www.reuters.com/article/us-usa-economy-spending/pent-up-demand-shortages-fuel-u-s-inflation-idUSKCN2D91EF
# 152 https://www.reuters.com/article/brief-ryanair-sees-fy-profit-at-lower-en/brief-ryanair-sees-fy-profit-at-lower-end-of-forecast-as-virus-hits-global-travel-idUSFWN2BQ1I4
# 153 https://www.reuters.com/article/us-usa-economy-spending/pent-up-demand-shortages-fuel-u-s-inflation-idUSKCN2D91EF#main-content
# 154 https://www.reuters.com/article/ryanair-britain/update-2-ryanair-cancels-12-uk-routes-over-disputed-caa-policy-shift-idUSL1N2J11J5
# 155 https://www.reuters.com/article/us-eu-summit-merkel/digital-vaccination-passports-likely-available-before-summer-merkel-says-idUSKBN2AP2OX
# 156 https://www.reuters.com/article/us-monsanto-dicamba-specialreport/special-report-the-decisions-behind-monsantos-weed-killer-crisis-idUSKBN1D91PZ
# 157 https://www.reuters.com/article/us-refinery-operations-stpaul-park-exclu/exclusive-worker-group-alleges-unsafe-practices-at-marathon-minnesota-refinery-idUSKBN2CC0JK
# 158 https://www.reuters.com/article/wells-fargo-compensation/about-57-of-votes-cast-in-favor-of-wells-fargos-2020-pay-plan-idUSL4N2MK42T
# 159 https://www.reuters.com/article/hyundai-motor-results/hyundai-motor-q1-profit-nearly-triples-on-luxury-car-demand-idUSS6N2LT00I
# 160 https://www.reuters.com/article/tyson-foods-results/tyson-foods-misses-sales-estimates-idUSL4N2KH1Q7
# 161 https://www.reuters.com/article/norway-oil/update-3-norway-oil-and-gas-output-at-risk-from-strike-equinor-says-idUSL1N2KI2F8
# 162 https://www.reuters.com/article/amazon-investors-workers/update-1-amazon-pressed-for-racial-equity-review-after-strong-vote-tally-idUSL2N2NF2TI
# 163 https://www.reuters.com/article/us-facebook-donations/facebook-extends-ban-on-donations-to-lawmakers-who-voted-against-biden-win-idUSKCN2D82YA
# 164 https://www.reuters.com/article/us-equinor-athabasca-oil-divestiture/equinor-divests-stake-in-canada-oil-sands-producer-athabasca-idUSKBN29P1R4
# 165 https://www.reuters.com/article/us-hongkong-security-detainees-feature/a-hong-kong-protesters-farewell-note-and-failed-escape-idUSKCN26F13Z
# 166 https://www.reuters.com/article/us-valero-election/u-s-refiner-valero-not-as-pessimistic-about-possible-biden-win-ceo-idUSKBN27728P
# 167 https://www.reuters.com/article/us-hyundai-motor-investment-usa/hyundai-to-invest-7-4-billion-in-u-s-by-2025-with-electric-cars-in-focus-idUSKBN2CU1J1
# 168 https://www.reuters.com/article/uk-britain-stocks/ftse-100-flat-as-losses-in-miners-energy-stocks-offset-gains-in-banks-idUSKCN2D90L2
# 169 https://www.reuters.com/article/eu-recovery-italy-reform/italy-to-approve-reform-decree-to-unlock-eu-recovery-funds-idUSL5N2NF33Y
# 170 https://www.reuters.com/article/us-usa-military-landlords/army-landlords-agree-to-expand-tenant-rights-curb-fees-in-latest-reform-to-reuters-reports-idUSKCN1QA2O6
# 171 https://www.reuters.com/article/us-hongkong-protests-china-liaison/china-removes-hong-kong-liaison-office-head-wang-zhimin-idUSKBN1Z30AD
# 172 https://www.reuters.com/article/usa-biden-budget-economy/bidens-big-budget-comes-with-a-modest-growth-outlook-for-an-aging-country-idUSL2N2NF24E#main-content
# 173 https://www.reuters.com/article/hyundai-motor-semiconductor/hyundai-motor-to-suspend-production-in-s-korea-due-to-chip-shortage-report-idUSL4N2LR2AI
# 174 https://www.reuters.com/article/hongkong-security-wealth/exclusive-global-banks-scrutinize-their-hong-kong-clients-for-pro-democracy-ties-sources-idINL2N2ER06S
# 175 https://www.reuters.com/article/usa-stocks/us-stocks-wall-street-shakes-off-inflation-rise-and-closes-higher-idUSL2N2NF2AS
# 176 https://www.reuters.com/article/us-valero-energy-outlook/valero-warns-of-bigger-first-quarter-loss-on-costs-from-texas-deep-freeze-idUSKBN2BV1WK
# 177 https://www.reuters.com/article/us-sk-innovation-hyundai-motor-electric/sk-innovation-to-work-with-hyundai-motor-kia-to-develop-hybrid-ev-batteries-idUSKBN2C3030
# 178 https://www.reuters.com/article/jbs-results/update-1-brazils-jbs-swings-back-to-profit-in-q1-on-strong-u-s-meat-business-idUSL1N2MZ3CU
# 179 https://www.reuters.com/article/us-usa-military-congress/senate-hearings-to-probe-unsafe-housing-of-u-s-military-families-idUSKCN1PO37F
# 180 https://www.reuters.com/article/japan-stocks-midday/japanese-shares-drop-as-economic-slump-prompts-investor-caution-idUSL3N2N60NZ
# 181 https://www.reuters.com/article/us-health-cancer-glyphosate/large-u-s-farm-study-finds-no-cancer-link-to-monsanto-weedkiller-idUSKBN1D916C
# 182 https://www.reuters.com/article/refinery-operations-total-portarthur/update-1-total-port-arthur-texas-refinery-restarts-small-crude-unit-sources-idUSL1N2GX2IM
# 183 https://www.reuters.com/article/uk-global-forex/u-s-dollar-dips-as-brexit-trade-deal-nears-sterling-gains-idUSKBN28X064
# 184 https://www.reuters.com/article/us-climate-change-offsets-insight/carbon-offsets-gird-for-lift-off-as-big-money-gets-close-to-nature-idUSKBN2AP1F2
# 185 https://www.reuters.com/article/us-usa-military-senate/senators-vow-urgent-reform-to-correct-unacceptable-military-housing-conditions-idUSKCN1Q3036
# 186 https://www.reuters.com/article/us-twitter-verification/after-verification-freeze-heres-how-you-can-get-twitters-blue-check-mark-idUSKCN2D11VI
# 187 https://www.reuters.com/article/climate-change-moodys-oil/moodys-flags-oil-majors-rising-credit-risk-after-shell-ruling-idUSL5N2NF21O
# 188 https://www.reuters.com/article/us-brf-litigation/brazils-brf-settles-u-s-class-action-suit-for-40-million-filing-idUSKBN2782SC
# 189 https://www.reuters.com/article/us-usa-weather-texas-puc/texas-ag-says-retroactive-power-price-cut-okay-regulator-ousted-idUSKBN2B90EC
# 190 https://www.reuters.com/article/brief-berkshire-hathaway-dissolves-share/brief-berkshire-hathaway-dissolves-share-stake-in-phillips-66-idUSFWN2CX17J
# 191 https://www.reuters.com/article/us-chile-copper-bhp/union-walks-off-job-at-bhps-escondida-spence-copper-mines-in-chile-idUSKCN2D81Z1
# 192 https://www.reuters.com/article/global-markets/refile-global-markets-equities-gain-dollar-weakens-on-rising-u-s-inflation-idUSL2N2NF1EY
# 193 https://www.reuters.com/article/legal-uk-blackrock-oil-votes/blackrock-goes-against-bp-board-in-climate-resolution-vote-idUSKCN2D92FH
# 194 https://www.reuters.com/article/us-blackrock-agm/blackrock-says-it-is-studying-crypto-but-cites-volatility-idUSKCN2D71M1
# 195 https://www.reuters.com/article/ip-genetics-patents/federal-circuit-affirms-bio-rad-infringed-rival-10x-genomics-patents-idUSL1N2MM384
# 196 https://www.reuters.com/article/us-qantas-bp-emissions/qantas-and-bp-unveil-strategic-partnership-to-reduce-carbon-emissions-idUSKBN29W31V
# 197 https://www.reuters.com/article/japan-stocks-close/japanese-shares-end-lower-as-pandemic-curbs-hit-risk-appetite-idUSL3N2N61H9
# 198 https://www.reuters.com/article/us-health-cancer-iarc/exclusive-u-s-congressional-committee-demands-answers-on-who-cancer-agency-idUSKBN14X011
# 199 https://www.reuters.com/article/us-refineries-storm-valero/no-significant-mechanical-damage-to-valero-refineries-from-winter-storm-ceo-idUSKBN2C91Z2
# 200 https://www.reuters.com/article/wells-fargo-results/wells-fargo-profit-surges-as-bank-commits-less-funds-for-potential-bad-loans-idUSL4N2M72Y7
# 201 https://www.reuters.com/article/us-usa-biden-budget-highlights-factbox/bidens-budget-plan-swells-u-s-debt-before-tax-hikes-kick-in-idUSKCN2D92EJ
# 202 https://www.reuters.com/article/marathon-petroleum-results/refiner-marathon-petroleum-posts-smaller-adjusted-loss-idUSL4N2MR1TX
# 203 https://www.reuters.com/article/crypto-currency-goldman-sachs/goldman-sachs-offers-bitcoin-derivatives-to-investors-bloomberg-news-idUSL4N2MT4QR
# 204 https://www.reuters.com/article/global-oil-phillips-66/refiner-phillips-66-cuts-spending-forecast-idUSL4N2BH3GV
# 205 https://www.reuters.com/article/welbilt-ma-aligroup/update-3-welbilt-says-ali-group-3-3-bln-bid-likely-better-than-middleby-deal-idUSL2N2NF21C
# 206 https://www.reuters.com/article/india-gas-reliance-bp/reliance-bp-consortium-invites-bidders-for-gas-from-kg-d6-basin-idUSL1N2JA098
# 207 https://www.reuters.com/article/total-apache/oil-firms-apache-and-total-make-second-major-oil-discovery-offshore-suriname-idUSL4N2BQ383
# 208 https://www.reuters.com/article/us-chile-copper/chile-royalty-bill-could-risk-1-million-t-of-future-copper-output-goldman-sachs-says-idUSKCN2D82HC
# 209 https://www.reuters.com/article/us-health-coronavirus-travel-insurance/covid-19-travel-insurance-becoming-a-vacation-staple-idUSKBN2AZ0DV
# 210 https://www.reuters.com/article/usa-bonds/treasuries-u-s-yields-fall-on-month-end-impact-investors-shrug-off-inflation-rise-idUSL2N2NF1LD
# 211 https://www.reuters.com/article/eurozone-bonds/update-2-dovish-ecb-prompts-second-week-of-italian-german-spread-tightening-idUSL2N2NF0QB
# 212 https://www.reuters.com/article/china-parliament-hongkong-finance/hong-kong-bankers-worry-that-new-laws-could-lead-to-capital-flight-idUSL4N2D41GI
# 213 https://www.reuters.com/article/us-refinery-operations-total-portarthur/total-port-arthur-texas-refinery-production-dips-to-70-of-capacity-sources-idUSKBN22Q2ZD
# 214 https://www.reuters.com/article/japan-stocks-midday/japanese-shares-extend-recovery-as-investors-shrug-off-gdp-data-idUSL2N2N505K
# 215 https://www.reuters.com/article/hongkong-security-banks/hong-kong-bank-account-freezes-rekindle-asset-safety-fears-idUSKBN28I1ZK
# 216 https://www.reuters.com/article/us-brazil-trafficking-cattle/jbs-among-meat-firms-linked-to-slavery-tainted-ranches-in-brazil-idUSKBN29A2EW
# 217 https://www.reuters.com/article/us-eu-recovery-italy-reform/italy-approves-reform-decree-to-unlock-eu-recovery-funds-idUSKCN2D925F
# 218 https://www.reuters.com/article/us-usa-biden-michigan/biden-pitches-174-billion-ev-plan-in-michigan-takes-truck-for-a-spin-idUSKCN2CZ0YE
# 219 https://www.reuters.com/article/us-ceraweek-bill-gates/bill-gates-urges-need-to-reduce-green-premium-in-energy-transition-idUSKBN2AT2Q4
# 220 https://www.reuters.com/article/global-forex-int/dollar-plumbs-more-than-two-year-lows-as-more-stimulus-in-view-idUSKBN29402M
# 221 https://www.reuters.com/article/us-myanmar-rohingya-un-exclusive-idUSKCN1NI1CI
# 222 https://www.reuters.com/article/us-apple-foxconn-india-exclusive/exclusive-foxconns-iphone-output-in-india-down-amid-covid-surge-sources-idUSKBN2CS0AV
# 223 https://www.reuters.com/article/factcheck-inflation-immigration/fact-check-meme-exaggerates-u-s-inflation-and-immigration-figures-idUSL2N2NF23Z
# 224 https://www.reuters.com/article/us-usa-military-congress/u-s-senators-citing-reuters-report-demand-fixes-in-military-housing-idUSKCN1NB03Q
# 225 https://www.reuters.com/article/us-usa-bonds-corporates/u-s-companies-issuing-bonds-in-foreign-markets-again-after-pandemic-drop-goldman-idUSKBN2CS1ZG
# 226 https://www.reuters.com/article/idUSKCN2D90U3
# 227 https://www.reuters.com/article/hungary-airport/update-1-hungarian-government-eyes-majority-stake-in-budapest-airport-idUSL2N2NF1E2
# 228 https://www.reuters.com/article/us-usa-autos-biden/biden-to-visit-ford-ev-facility-in-michigan-next-tuesday-idUSKBN2CS24Z
# 229 https://www.reuters.com/article/us-taiwan-forex/taiwan-punishes-deutsche-bank-others-in-currency-speculation-case-idUSKBN2A705J
# 230 https://www.reuters.com/article/china-morgan-stanley/morgan-stanley-nears-full-ownership-of-china-ventures-with-stake-buys-idUSL3N2NE151
# 231 https://www.reuters.com/article/us-bank-of-america-layoffs/bank-of-america-reduces-staff-in-investment-banking-and-trading-bloomberg-news-idUSKBN2AP2JR
# 232 https://www.reuters.com/article/usa-stocks-meme/update-3-amc-shares-retreat-but-end-week-up-116-after-4-day-rally-idUSL2N2NF1AL#main-content
# 233 https://www.reuters.com/article/us-twitter-spaces/twitter-to-introduce-ticketing-for-audio-spaces-feature-idUSKBN2CK1K2
# 234 https://www.reuters.com/article/brief-ryanair-welcomes-spain-reopening-f/brief-ryanair-welcomes-spain-reopening-for-tourism-from-july-1-idUSFWN2D80BJ
# 235 https://www.reuters.com/article/europe-stocks/european-shares-hover-below-record-highs-hsbc-edges-lower-idUSL3N2NE237
# 236 https://www.reuters.com/article/us-morgan-stanley-shareholders-meeting/morgan-stanley-investors-back-bank-directors-executive-pay-packages-idUSKCN2D11SL
# 237 https://www.reuters.com/article/us-change-suite-shakeshack/loud-and-proud-shake-shacks-recipe-for-an-inclusive-workplace-idUSKBN2C10DQ
# 238 https://www.reuters.com/article/global-markets/global-markets-equities-dollar-gain-on-rising-u-s-inflation-idUSL2N2NF2PD
# 239 https://www.reuters.com/article/us-myanmar-rohingya-messages-insight/we-are-always-missing-you-torn-apart-by-violence-rohingya-families-connect-through-letters-idUSKBN1K31QH
# 240 https://www.reuters.com/article/us-foxconn-yageo/taiwans-foxconn-forms-semiconductor-jv-with-yageo-idUSKBN2CM0MA
# 241 https://www.reuters.com/article/usa-environment-lawsuit/baltimore-asks-scotus-to-send-climate-case-back-to-state-court-idUSL1N2IX03G
# 242 https://www.reuters.com/article/us-health-coronavirus-usa-meat/u-s-congress-panel-investigating-covid-19-worker-safety-at-meatpacking-firms-idUSKBN2A12XD
# 243 https://www.reuters.com/article/us-bitcoin-tezos-lawsuits-exclusive/exclusive-tezos-founders-push-for-legal-bailout-from-swiss-foundation-idUSKBN1DV4K0
# 244 https://www.reuters.com/article/uk-factcheck-vaccine-microchip-gates-ma-idUSKBN28E286
# 245 https://www.reuters.com/article/us-hongkong-extradition-pla-exclusive/exclusive-chinas-pla-signals-it-will-keep-hong-kong-based-troops-in-barracks-idUSKCN1U40QR
# 246 https://www.reuters.com/article/us-caterpillar-results/caterpillar-earnings-dive-as-coronavirus-wreaks-economic-havoc-idUSKCN22A1JS
# 247 https://www.reuters.com/article/ryanair-results/ryanair-posts-first-summer-loss-in-decades-flags-winter-capacity-cut-idUSL8N2HK8OO
# 248 https://www.reuters.com/article/rivian-ipo/electric-vehicle-firm-rivian-could-seek-70-bln-valuation-in-ipo-bloomberg-news-idUSL3N2NF3S1
# 249 https://www.reuters.com/article/idUSKCN2D70C2
# 250 https://www.reuters.com/article/airlines-iata-environment/airline-body-sees-big-oil-backlash-as-catalyst-for-green-fuels-idUSL5N2NF2PU
# 251 https://www.reuters.com/article/us-britain-economy-inflation/uk-short-term-inflation-expectations-cool-slightly-citi-yougov-idUSKCN2D90UU
# 252 https://www.reuters.com/article/ford-india-protests/workers-at-fords-southern-india-plant-seek-halt-amid-covid-19-surge-idUSL2N2NE0P9
# 253 https://www.reuters.com/article/emerging-markets-asia/emerging-markets-taiwan-leads-most-asian-shares-higher-malaysia-down-on-covid-19-hit-idUSL3N2NF1K9
# 254 https://www.reuters.com/article/us-stellantis-foxconn-partnership/stellantis-to-detail-foxconn-strategic-partnership-on-tuesday-idUSKCN2CY0JJ
# 255 https://www.reuters.com/article/wejo-ma-spac/update-1-wejo-to-go-public-deal-values-auto-data-startup-at-800-mln-idUSL2N2NF2D8
# 256 https://www.reuters.com/article/us-usa-cyber-congress/u-s-lawmakers-call-on-spy-chief-to-rein-in-spread-of-hacking-tools-idUSKCN1SQ1ZK
# 257 https://www.reuters.com/article/us-global-markets-themes/take-five-ecb-earnings-and-geopolitical-escalations-idUSKBN2C31LP
# 258 https://www.reuters.com/article/japan-stocks-close/japanese-shares-drop-as-coronavirus-infections-weigh-on-sentiment-idUSL2N2N40BS
# 259 https://www.reuters.com/article/us-exxon-mobil-agm-vote-count/full-results-at-exxon-mobil-board-may-take-until-next-week-idUSKCN2D82GH
# 260 https://www.reuters.com/article/health-coronavirus-latest/factbox-latest-on-the-worldwide-spread-of-the-coronavirus-idUSL4N2KI0XB
# 261 https://www.reuters.com/article/hyundai-motor-investment-usa/hyundai-motor-to-invest-7-4-bln-in-the-u-s-by-2025-idUSL4N2N03MW
# 262 https://www.reuters.com/article/usa-autos-biden/biden-to-visit-ford-ev-facility-in-michigan-tuesday-idUSL1N2MY1RP
# 263 https://www.reuters.com/article/us-fortescue-project-iron-bridge/miner-fortescue-lifts-cost-estimate-again-delays-start-of-iron-bridge-project-idUSKCN2D906N
# 264 https://www.reuters.com/article/us-suriname-oil/surinames-staatsolie-weighs-farm-in-to-total-apache-block-after-discovery-idUSKBN24Y0TR
# 265 https://www.reuters.com/article/valero-energy-results/update-2-refiner-valero-posts-smaller-than-expected-loss-pins-recovery-hopes-on-vaccine-rollout-idUSL4N2K339U
# 266 https://www.reuters.com/article/us-extended-stay-m-a/iss-recommends-extended-stays-shareholders-to-vote-against-blackstones-takeover-offer-idUSKCN2D91ND
# 267 https://www.reuters.com/article/foxconn-results/apple-supplier-foxconn-q4-profit-misses-estimates-idUSB9N2L2003
# 268 https://www.reuters.com/article/us-global-finance-breakingviews/capital-calls-morgan-stanleys-stars-realign-idUSKCN2D11XT
# 269 https://www.reuters.com/article/us-equinor-agm-climate/equinor-asks-shareholders-to-reject-intermediate-scope-3-emissions-targets-idUSKBN2C61JW
# 270 https://www.reuters.com/article/phillips-66-results/refiner-phillips-66-posts-quarterly-loss-as-virus-hits-fuel-demand-idUSL3N2F242Q
# 271 https://www.reuters.com/article/us-norway-oil-spill/norway-regulator-to-investigate-equinor-oil-spill-idUSKBN2CK0OR
# 272 https://www.reuters.com/article/southkorea-markets-midday/s-korea-stocks-set-for-1-weekly-gain-as-u-s-data-supports-idUSL2N2NF03F
# 273 https://www.reuters.com/article/brief-ryanair-says-co-extending-limited/brief-ryanair-says-co-extending-limited-flight-schedule-for-eu-by-a-week-to-april-9-idUSFWN2BN1GS
# 274 https://www.reuters.com/article/weir-group-divestiture-caterpillar/weir-group-to-sell-oil-gas-division-to-caterpillar-for-405-million-idUSL4N2GW15G
# 275 https://www.reuters.com/article/us-bitcoin-tezos/tezos-organizers-hit-with-second-lawsuit-over-cryptocurrency-fundraiser-idUSKBN1DF37L?il=0
# 276 https://www.reuters.com/article/us-refinery-operations-marathon-galvesto/marathon-galveston-bay-refinery-in-texas-restarts-reformer-coker-sources-idUSKBN2B405D
# 277 https://www.reuters.com/article/us-caterpillar-results/caterpillar-hopes-for-a-better-2021-on-improving-market-conditions-idUSKBN29Y1EG
# 278 https://www.reuters.com/article/papua-lng-total/papua-new-guinea-frances-total-sign-fiscal-agreement-for-papua-lng-project-idUSM0N285015
# 279 https://www.reuters.com/article/us-australia-oil-refineries/exxon-to-close-australian-refinery-idUSKBN2A933Z
# 280 https://www.reuters.com/article/sprinklr-ipo/update-1-software-provider-sprinklr-reveals-19-jump-in-revenue-in-ipo-filing-idUSL3N2NF3U0
# 281 https://www.reuters.com/article/global-forex/dollar-turns-higher-as-risk-sentiment-wanes-idUSKBN2991SN
# 282 https://www.reuters.com/article/us-usa-cyber-mozilla/mozilla-blocks-uae-bid-to-become-an-internet-security-guardian-after-hacking-reports-idUSKCN1U42CA
# 283 https://www.reuters.com/article/us-usa-barr-senate/senators-examine-caterpillar-tax-probe-under-former-ag-barrs-office-idUSKBN2CG2FE
# 284 https://www.reuters.com/article/india-stocks/indias-blue-chip-nifty-50-hits-record-high-as-covid-19-cases-drop-idUSL3N2NF15Y
# 285 https://www.reuters.com/article/us-redecan-m-a-hexo/hexo-steps-up-cannabis-ma-spree-with-c925-million-redecan-deal-idUSKCN2D913Y
# 286 https://www.reuters.com/article/legal-us-russia-technology-socialmedia/facebook-twitter-told-to-open-databases-in-russia-by-july-ifax-idUSKCN2D715D
# 287 https://www.reuters.com/article/us-bitcoin-tezos-refunds/no-refund-for-tezos-contributors-cryptocurrency-broker-says-idUSKBN1DF2JQ
# 288 https://www.reuters.com/article/health-coronavirus-india-twitter/covidsos-india-twitter-paints-desperate-picture-of-covid-19-crisis-idUSKBN2CO0SB
# 289 https://www.reuters.com/article/us-foxconn-vinfast-electric-exclusive/exclusive-foxconn-and-vietnams-vinfast-explore-partnership-talks-focus-on-batteries-ev-parts-idUSKBN2BB0JH
# 290 https://www.reuters.com/article/us-usa-products-valero-energy-storage/valero-charters-tanker-for-gulf-coast-storage-amid-pipeline-outage-sources-idUSKBN2CR03U
# 291 https://www.reuters.com/article/us-berkshire-buffett-wells-fargo/berkshire-sheds-nearly-all-of-wells-fargo-a-holding-since-1989-idUSKCN2CY2GC
# 292 https://www.reuters.com/article/us-fisker-foxconn-electric-vehicle/fisker-finalizes-deal-with-foxconn-to-make-evs-in-u-s-starting-in-2023-idUSKBN2CU2B0
# 293 https://www.reuters.com/article/us-usa-products-gasoline/u-s-drivers-to-get-hit-by-soaring-pump-prices-over-memorial-day-holiday-idUSKCN2D815U
# 294 https://www.reuters.com/article/us-reifnery-operations-total-portarthur/total-continues-restart-of-port-arthur-refinery-sources-idUSKBN26W0WB
# 295 https://www.reuters.com/article/us-usa-military-airforce-exclusive/exclusive-air-force-to-push-congress-for-military-housing-tenant-bill-of-rights-idUSKCN1Q71WH
# 296 https://www.reuters.com/article/us-health-coronavirus-britain-hometests/exclusive-uks-home-testing-dogged-by-delays-undermining-push-to-reduce-virus-transmission-idUSKCN24P0RO
# 297 https://www.reuters.com/article/us-malta-daphne-offshore-exclusive/exclusive-mystery-company-named-by-murdered-maltese-journalist-is-linked-to-power-station-developer-idUSKCN1NE18M
# 298 https://www.reuters.com/article/global-markets/global-markets-stocks-push-for-record-high-on-6-trillion-u-s-spending-hopes-idUSL5N2NF20E
# 299 https://www.reuters.com/article/us-usa-court-wells-fargo/u-s-supreme-court-refuses-to-revive-wells-fargo-accounts-scandal-suit-idUSKBN2CK12I
# 300 https://www.reuters.com/article/us-refinery-operations-phillips66-storm/storm-prompts-phillips-66-to-start-shutdown-of-lake-charles-la-facility-idUSKBN25L0AD
# 301 https://www.reuters.com/article/idUSL1N2M821Y
# 302 https://www.reuters.com/article/us-usa-products-colonial-marathon/marathon-working-on-other-logistics-to-supply-customers-if-colonial-outage-extended-idUSKBN2CR16H
# 303 https://www.reuters.com/article/europe-stocks/update-3-european-shares-hit-record-high-on-airbus-boost-bayer-hurt-by-roundup-ruling-idUSL3N2NE26R
# 304 https://www.reuters.com/article/phillips-66-results/refiner-phillips-66-posts-quarterly-loss-as-coronavirus-hits-fuel-demand-idUSL4N2CJ1SA
# 305 https://www.reuters.com/article/us-bankofamerica-usa/bank-of-america-ceo-moynihan-says-supports-a-well-focused-infrastructure-plan-cnn-interview-idUSKBN2C31MM
# 306 https://www.reuters.com/article/us-brazil-autos-insight/how-ford-burned-12-billion-in-brazil-idUSKCN2D110X
# 307 https://www.reuters.com/article/us-usa-biden-budget-gig-workers/enforcing-gig-worker-rights-gets-a-boost-in-bidens-budget-idUSKCN2D9283
# 308 https://www.reuters.com/article/refinery-operations-valero-mckee/valero-mckee-refinery-sunray-texas-shuts-cdu-other-units-for-work-sources-idUSKBN28H1QW
# 309 https://www.reuters.com/article/global-markets-themes/graphic-take-five-a-looming-labour-crunch-idUSL5N2NE669
# 310 https://www.reuters.com/article/us-global-markets-themes/take-five-employment-e-yuan-and-elections-idUSKBN2CH1JP
# 311 https://www.reuters.com/article/factcheck-nasa-zodiac/fact-check-false-posts-about-nasa-changing-the-zodiac-resurface-idUSL2N2NF2AW
# 312 https://www.reuters.com/article/us-ryanair-lawsuit/ryanair-must-face-u-s-shareholder-lawsuit-over-unionization-comments-idUSKBN2383SL
# 313 https://www.reuters.com/article/fintech-crypto-bitcoin/bitcoin-slumps-8-as-it-heads-for-bruising-monthly-drop-idUSL5N2NF2NG#main-content
# 314 https://www.reuters.com/article/us-usa-refinery-bp-exclusive/exclusive-bp-gives-caribbean-refinery-more-time-to-hit-operating-targets-sources-idUSKBN29B2KG
# 315 https://www.reuters.com/article/us-usa-congress-bank-ceos/senator-warren-attacks-jpmorgans-dimon-over-baloney-overdraft-fees-idUSKCN2D71YR
# 316 https://www.reuters.com/article/factcheck-covid-needle-microchip/fact-check-needle-in-animal-microchip-video-not-used-in-covid-19-vaccine-injections-idUSL2N2NE0P0
# 317 https://www.reuters.com/article/foxconn-results/apple-supplier-foxconn-reports-q1-profit-t28-2-bln-beats-estimates-idUSP8N2MT02G
# 318 https://www.reuters.com/article/us-refinery-operations-marathon-st-paul/marathon-and-teamsters-at-an-impasse-at-st-paul-park-refinery-letter-to-union-idUSKBN2CN262
# 319 https://www.reuters.com/article/brazil-brf-canada/brazils-brf-gets-nod-to-export-chicken-wings-to-canada-idUSL1N2LE1M0
# 320 https://www.reuters.com/article/us-global-oil-kemp/big-oil-shareholders-revolt-over-poor-long-run-returns-kemp-idUSKCN2D826Y
# 321 https://www.reuters.com/article/us-usa-markets-blocktrades-wells-fargo-d/wells-fargo-says-no-losses-from-archegos-downfall-idUSKBN2BM28T
# 322 https://www.reuters.com/article/brazil-meatpacking/wrapup-1-brazil-meatpackers-jbs-brf-stung-by-feed-costs-in-home-market-idUSL1N2N02FK
# 323 https://www.reuters.com/article/hyundai-motor-results/preview-hyundai-q1-profit-to-triple-on-luxury-car-demand-but-chip-shortage-starts-to-hurt-idUSL4N2MC1GS
# 324 https://www.reuters.com/article/us-jbs-results/brazils-jbs-profit-bolstered-by-weak-currency-strong-chinese-and-u-s-markets-idUSKBN2BG3E2
# 325 https://www.reuters.com/article/us-bp-boston-dynamics-robot-oil-rig-chan/boston-dynamics-dog-robot-spot-learns-new-tricks-on-bp-oil-rig-idUSKBN28E2D0
# 326 https://www.reuters.com/article/us-senior-m-a-lone-star/uk-parts-supplier-senior-rejects-lone-stars-over-1-billion-offer-idUSKCN2D91KW
# 327 https://www.reuters.com/article/amazon-investors-workers/call-for-amazon-to-consider-blue-collar-director-wins-17-support-idUSL2N2NF2T0
# 328 https://www.reuters.com/article/global-markets/refile-global-markets-equities-gain-dollar-weakens-on-rising-u-s-inflation-idUSL2N2NF1EY#main-content
# 329 https://www.reuters.com/article/us-welbilt-m-a-aligroup/welbilt-says-ali-group-3-3-billion-bid-likely-better-than-middleby-deal-idUSKCN2D91UQ
# 330 https://www.reuters.com/article/us-eu-facebook-antitrust/facebook-marketplace-faces-eu-antitrust-probe-source-idUSKCN2D71CR
# 331 https://www.reuters.com/article/us-twitter-ark/cathie-woods-investment-firm-elliott-buy-twitter-shares-on-dip-bloomberg-news-idUSKBN2CK1JO
# 332 https://www.reuters.com/article/factcheck-deer-man/fact-check-story-of-man-who-self-identifies-as-a-deer-stems-from-satire-idUSL2N2NE2BN
# 333 https://www.reuters.com/article/us-asia-m-a-tech/tech-ma-in-asia-at-record-high-main-deal-driver-in-the-region-industry-data-idUSKCN2D80IW
# 334 https://www.reuters.com/article/us-oil-search-strategy/oil-search-sees-totals-papua-lng-advancing-ahead-of-exxons-pnyang-idUSKBN27Y2WC
# 335 https://www.reuters.com/article/emerging-markets-latam/emerging-markets-most-latam-currencies-weaken-chilean-peso-at-over-3-mth-high-idUSL1N2MD28B
# 336 https://www.reuters.com/article/us-facebook-influence/u-s-a-top-target-for-foreign-and-domestic-influence-operations-says-new-facebook-report-idUSKCN2D718Y
# 337 https://www.reuters.com/article/us-russia-twitter/russian-court-fines-twitter-for-failing-to-delete-content-idUSKCN2D818J
# 338 https://www.reuters.com/article/us-usa-army-reform/u-s-army-vows-more-funds-measures-to-fix-housing-hazards-idUSKBN1WO28T
# 339 https://www.reuters.com/article/factcheck-vaccine-antibodies-plasma/fact-check-covid-19-vaccines-dont-strip-people-of-their-antibodies-vaccinated-individuals-can-donate-blood-idUSL2N2NF0YM
# ...
# 745 https://www.reuters.com/article/brief-facebook-lifts-ban-on-posts-claimi/brief-facebook-lifts-ban-on-posts-claiming-covid-19-was-man-made-politico-idUSFWN2ND0ZE
# 746 https://www.reuters.com/article/us-europe-stocks/european-stocks-hover-near-record-highs-cineworld-gains-idUSKCN2D50HP
# 747 https://www.reuters.com/article/us-tyson-foods-results/tyson-foods-expects-costs-to-hit-profit-lifts-revenue-outlook-idUSKBN2CR13I
# 748 https://www.reuters.com/article/us-exxon-mobil-agm-fund/activist-hedge-fund-accuses-exxon-of-delaying-vote-to-avoid-proxy-fight-loss-idUSKCN2D7233
# 749 https://www.reuters.com/article/southkorea-markets-close/s-korea-stocks-rise-on-auto-strength-upbeat-u-s-data-post-1-weekly-gain-idUSAZN21Z700
# 750 https://www.reuters.com/article/legal-us-nerdwallet-ipo/exclusive-personal-finance-startup-nerdwallet-files-for-u-s-ipo-sources-idUSKBN2CV2B9
# 751 https://www.reuters.com/article/uk-health-coronavirus-schools-reopening/special-report-to-reopen-or-not-to-reopen-that-is-the-fraught-question-for-u-s-schools-idUKKBN2851M6
# 752 https://www.reuters.com/article/us-global-oil/oil-gains-more-than-1-on-fuel-demand-optimism-idUSKBN2CF06O
# 753 https://www.reuters.com/article/us-total-australia/frances-total-looks-to-expand-in-australia-selling-power-idUSKBN22G06Q
# 754 https://www.reuters.com/article/us-hongkong-protests-shenzhen-exclusive/exclusive-china-sets-up-hong-kong-crisis-center-in-mainland-considers-replacing-chief-liaison-idUSKBN1Y000P
# 755 https://www.reuters.com/article/swiss-snb-jordan/snb-chairman-sees-only-modest-inflation-risk-in-switzerland-schweiz-am-wochenende-idUSL2N2NG048
# 756 https://www.reuters.com/article/us-health-coronavirus-bank-of-america/bank-of-america-to-hand-out-pay-hikes-to-junior-investment-bankers-memo-idUSKBN2BV2ML
# 757 https://www.reuters.com/article/us-usa-jails-hearing/georgia-legislators-citing-reuters-report-want-every-jail-death-investigated-idUSKBN29U2B7
# 758 https://www.reuters.com/article/us-usa-court-barrett-police-analysis/analysis-u-s-supreme-court-nominee-barrett-often-rules-for-police-in-excessive-force-cases-idUSKBN27A0C1
# 759 https://www.reuters.com/article/global-oil-tax-havens/special-report-how-oil-majors-shift-billions-in-profits-to-island-tax-havens-idUSKBN28J1IK
# 760 https://www.reuters.com/article/us-usa-military-senate/u-s-senators-call-for-banning-prosecuting-slumlords-of-military-housing-idUSKBN1Y72HP
# 761 https://www.reuters.com/article/campari-share-sale/goldman-sachs-selling-3-7-million-campari-shares-linked-to-stock-option-plans-idUSKBN2CT2IW
# 762 https://www.reuters.com/article/jpmorgan-shareholders-meeting/jpmorgan-shareholders-vote-to-back-board-members-executive-compensation-idUSL2N2N51GM
# 763 https://www.reuters.com/article/us-usa-jails-doj/congress-presses-doj-to-improve-jail-reporting-system-after-reuters-report-idUSKBN2761L9
# 764 https://www.reuters.com/article/us-brf-marfrig/brazils-marfrig-buys-800-million-stake-in-brf-becoming-its-top-shareholder-idUSKCN2D22S7
# 765 https://www.reuters.com/article/legal-us-tyson-foods-divestiture-general/general-mills-beefs-up-pet-foods-division-with-1-2-billion-tyson-unit-purchase-idUSKBN2CV2CE
# 766 https://www.reuters.com/article/us-tyson-foods-chicken-settlement/tyson-foods-to-pay-221-5-million-to-settle-some-chicken-price-fixing-claims-idUSKBN29O2IK
# 767 https://www.reuters.com/article/us-usa-raven-congress/new-u-s-law-requires-government-to-report-risks-of-overseas-activities-by-ex-spies-idUSKBN1ZL2WJ
# 768 https://www.reuters.com/article/us-bofaml-morgan-stanley-spoofing/bank-of-america-morgan-stanley-win-dismissal-of-metals-spoofing-litigation-idUSKBN2AW2NT
# 769 https://www.reuters.com/article/us-exxon-mobil-agm-state-street/top-exxon-investors-state-street-vanguard-backed-activist-nominees-idUSKCN2D82XY
# 770 https://www.reuters.com/article/us-philippines-drugs-children-insight/duterte-targets-philippine-children-in-bid-to-widen-drug-war-idUSKBN15T1NB
# 771 https://www.reuters.com/article/us-europe-gas-equinor/european-gas-demand-set-to-grow-by-2-in-2021-equinor-says-idUSKBN2BG2OH
# 772 https://www.reuters.com/article/europe-stocks/update-2-european-stocks-hover-near-record-highs-cineworld-gains-idUSL3N2NB1WK
# 773 https://www.reuters.com/article/us-health-coronavirus-brf/brazils-brf-registers-1138-covid-19-cases-at-a-single-meat-plant-state-data-shows-idUSKCN2562KS
# 774 https://www.reuters.com/article/us-valero-energy-results/refiner-valero-posts-better-than-expected-results-raises-renewables-bet-idUSKBN2771FU
# 775 https://www.reuters.com/article/uk-global-forex/risk-currencies-recover-from-friday-carnage-dollar-consolidates-idUSKCN2AT0WL
# 776 https://www.reuters.com/article/us-ecuador-oil/ecuadors-petroecuador-awards-phillips-66-tender-to-buy-oriente-crude-idUSKBN2413DI
# 777 https://www.reuters.com/article/us-tyson-foods-coronavirus-investors/tyson-foods-to-face-investor-pressure-over-lobbying-human-rights-at-shareholder-meeting-idUSKBN2AA2XR
# 778 https://www.reuters.com/article/us-northkorea-china-art-insight/white-tiger-dark-horse-north-korean-art-market-heats-up-idUSKCN1C90Z0
# 779 https://www.reuters.com/article/legal-us-shell-netherlands-court-decisio/eyes-on-u-s-climate-lawsuits-after-landmark-dutch-ruling-idUSKCN2D8217
# 780 https://www.reuters.com/article/us-usa-refining-valero-energy/used-cooking-oil-a-renewable-fuels-feedstock-nearly-tapped-out-in-u-s-valero-idUSKBN2C92KB
# 781 https://www.reuters.com/article/us-total-apache-suriname/apache-total-make-third-oil-discovery-offshore-suriname-idUSKCN24U38Q
# 782 https://www.reuters.com/article/us-hongkong-extradition-capitalflight-ex/exclusive-hong-kong-tycoons-start-moving-assets-offshore-as-fears-rise-over-new-extradition-law-idUSKCN1TF1DZ
# 783 https://www.reuters.com/article/japan-stocks-close/japanese-shares-inch-higher-as-chip-gains-offset-losses-in-cyclicals-idUSL3N2N71M0
# 784 https://www.reuters.com/article/us-mcguire-citigroup-mayor/citi-to-pay-ny-mayor-candidate-and-former-executive-mcguire-over-5-7-million-idUSKBN2C92WG
# 785 https://www.reuters.com/article/caterpillar-results/caterpillar-reports-lower-q3-earnings-idUSL4N2HH3LK
# 786 https://www.reuters.com/article/health-coronavirus-usa-equipment/how-deere-caterpillar-kept-plants-running-during-the-coronavirus-outbreak-idUSL4N2CO3D4
# 787 https://www.reuters.com/article/refinery-operations-marathon-galvestonba/most-units-shut-at-marathon-galveston-bay-refinery-due-to-cold-weather-sources-idUSL1N2KL0VE
# 788 https://www.reuters.com/article/europe-stocks/european-shares-inch-closer-to-record-high-idUSL3N2NF1RF
# 789 https://www.reuters.com/article/factcheck-coronavirus-vaccine-idUSL2N2N41KA
# 790 https://www.reuters.com/article/us-global-markets-themes/take-five-whos-afraid-of-u-s-inflation-idUSKBN2BW1MS
# 791 https://www.reuters.com/article/rivian-ipo/update-1-electric-vehicle-firm-rivian-could-seek-70-bln-valuation-in-ipo-bloomberg-news-idUSL3N2NF3V9
# 792 https://www.reuters.com/article/us-phillips-66-results/phillips-66-posts-smaller-than-expected-q1-loss-as-refining-margins-improve-idUSKBN2CH1C4
# 793 https://www.reuters.com/article/us-refinery-operations-valero-portarthur/valero-port-arthur-texas-refinery-restarts-large-crude-unit-sources-idUSKBN2AP33F
# 794 https://www.reuters.com/article/wells-fargo-workers/wells-fargo-plans-on-bringing-workers-back-to-office-in-september-wsj-idUSL4N2LS4O8
# 795 https://www.reuters.com/article/us-goldman-moves-nahar/goldman-hires-uber-executive-to-run-its-consumer-bank-idUSKCN2CY1O1
# 796 https://www.reuters.com/article/us-global-markets-themes-graphic/take-five-testing-times-idUSKBN2AX15A
# 797 https://www.reuters.com/article/us-refinery-operations-marathon-ptrlum/marathon-petroleum-probing-cause-of-chemical-release-at-texas-refinery-idUSKBN2CM2HG
# 798 https://www.reuters.com/article/us-citigroup-moves-investor-relations/citigroup-names-landis-as-head-of-investor-relations-memo-idUSKCN2D0237
# 799 https://www.reuters.com/article/global-markets-int/equities-dollar-gain-on-rising-u-s-inflation-idUSKCN2D925N
# 800 https://www.reuters.com/article/usa-stocks/us-stocks-wall-street-ends-mixed-despite-bumper-bank-earnings-idUSL1N2M72M8
# 801 https://www.reuters.com/article/us-global-markets-themes/take-five-quarter-end-tug-of-war-idUSKBN2BI1U5
# 802 https://www.reuters.com/article/health-coronavirus-latest/factbox-latest-on-the-worldwide-spread-of-the-coronavirus-idUSL4N2KI0XB#main-content
# 803 https://www.reuters.com/article/us-ceraweek-oil-investment/oil-executives-expect-crude-demand-to-climb-even-as-renewables-are-in-vogue-idUSKBN2AT33R
# 804 https://www.reuters.com/article/us-myanmar-investigation-usa-exclusive/exclusive-u-s-team-in-refugee-camps-investigating-atrocities-against-rohingya-idUSKBN1HW1N9
# 805 https://www.reuters.com/article/us-hongkong-security-democracy/exclusive-china-plans-further-hong-kong-crackdown-after-mass-arrest-sources-idUSKBN29H0E8
# 806 https://www.reuters.com/article/exxon-mobil-agm-vote-count/full-results-at-exxon-mobil-board-may-take-until-next-week-company-idUSL2N2NE2BK
# 807 https://www.reuters.com/article/us-ford-recall/ford-recalls-661000-explorer-suvs-in-north-america-idUSKBN2CQ08X
# 808 https://www.reuters.com/article/us-whatsapp-colombia/colombia-orders-whatsapp-to-comply-with-data-protection-rules-idUSKCN2D72ME
# 809 https://www.reuters.com/article/global-forex-int/more-weakness-seen-as-dollar-posts-worst-year-since-2017-idUSKBN29501O
# 810 https://www.reuters.com/article/us-stellantis-foxconn-partnership/stellantis-foxconn-to-form-connectivity-focused-car-technology-jv-idUSKCN2CZ10A
# 811 https://www.reuters.com/article/china-stocks-hongkong-close/hong-kong-stocks-end-flat-post-best-week-in-over-3-months-idUSL2N2NF0IO
# 812 https://www.reuters.com/article/us-usa-biden-budget-economy/bidens-big-budget-comes-with-a-modest-growth-outlook-for-an-aging-country-idUSKCN2D92JF#main-content
# 813 https://www.reuters.com/article/uk-global-oil/brent-ends-at-two-year-high-as-demand-outlook-counters-supply-fears-idUSKCN2D903R
# 814 https://www.reuters.com/article/usa-biden-budget-reaction/factbox-bidens-6-trillion-budget-plan-draws-partisan-scorn-and-praise-idUSL2N2NF24V
# 815 https://www.reuters.com/article/britain-stocks/ftse-100-rises-on-banks-commodity-boost-idUSL3N2NF1TT
# 816 https://www.reuters.com/article/us-tellurian-lng-gunvor/tellurian-to-sell-lng-to-gunvor-delays-louisiana-project-start-idUSKCN2D82B4
# 817 https://www.reuters.com/article/us-philippines-drugs-mayor/between-duterte-and-a-death-squad-a-philippine-mayor-fights-drug-war-violence-idUSKBN16N33I
# 818 https://www.reuters.com/article/us-tyson-food-vaccine/tyson-to-offer-vaccinations-to-thousands-of-iowa-meat-plant-workers-idUSKCN2AT2BM
# 819 https://www.reuters.com/article/us-usa-cyber-congress/lawmakers-seek-probe-on-u-s-hacking-services-sold-globally-idUSKCN1SL2WE
# 820 https://www.reuters.com/article/total-results/total-back-to-pre-pandemic-profit-levels-as-oil-prices-rise-idUSP6N2LY009
# 821 https://www.reuters.com/article/uk-global-forex/covid-19-proof-risk-sentiment-drags-dollar-near-2018-lows-idUSKBN29902F
# 822 https://www.reuters.com/article/us-jbs-outlook/brazil-meatpacker-jbs-positive-on-china-meat-imports-outlook-idUSKBN2BH1ZM
# 823 https://www.reuters.com/article/factcheck-israel-gaza/fact-check-israels-iron-dome-does-not-form-a-star-of-david-when-intercepting-missiles-idUSL2N2ND1LA
# 824 https://www.reuters.com/article/us-health-coronavirus-bofaml/bank-of-america-jpmorgan-give-u-s-staff-paid-time-off-for-covid-19-vaccinations-memo-idUSKBN2AQ2GA
# 825 https://www.reuters.com/article/factcheck-walmart-racist/fact-check-walmart-says-it-did-not-send-offensive-email-to-customers-idUSL2N2NF23K
# 826 https://www.reuters.com/article/us-caterpillar-results-preview/caterpillar-results-likely-to-shed-light-on-strength-of-economic-recovery-idUSKCN24T29V
# 827 https://www.reuters.com/article/us-usa-military-command/senator-blumenthal-seeks-criminal-investigation-of-shoddy-military-housing-idUSKCN1QO2ID
# 828 https://www.reuters.com/article/eicher-motors-labour-unrest/indias-eicher-motors-says-labour-strife-hurt-royal-enfield-production-idUSL3N1XB5PE
# 829 https://www.reuters.com/article/us-global-forex/dollar-rebounds-off-march-2018-low-as-georgia-elections-point-to-dem-sweep-idUSKBN29B07J
# 830 https://www.reuters.com/article/us-refinery-operations-marathon-galvesto/marathon-to-shut-galveston-bay-fcc-other-units-in-mid-feb-for-overhaul-sources-idUSKBN2A337Y
# 831 https://www.reuters.com/article/us-hyundai-motor-electric-recall/kona-ev-owners-say-hyundai-mishandling-recall-for-battery-fires-idUSKBN2BG3ET
# 832 https://www.reuters.com/article/idUSKCN2D70C2#main-content
# 833 https://www.reuters.com/article/us-hyundai-motor-results/hyundai-q1-profit-triples-to-adjust-may-auto-production-due-to-chip-shortage-idUSKBN2C90EY
# 834 https://www.reuters.com/article/us-exxon-mobil-agm-t-rowe-price-grp/t-rowe-price-backed-activist-nominees-in-exxon-board-contest-idUSKCN2D92A0
# 835 https://www.reuters.com/article/global-forex/forex-dollar-edges-up-ahead-of-inflation-data-yen-falls-idUSL2N2NF0G1
# 836 https://www.reuters.com/article/us-usa-military-raid/air-force-agents-raid-military-landlords-oklahoma-office-seize-computers-idUSKBN1ZD2II
# 837 https://www.reuters.com/article/us-health-coronavirus-usa-equipment/how-deere-caterpillar-kept-plants-running-during-the-coronavirus-outbreak-idUSKBN22J2R5
# 838 https://www.reuters.com/article/factcheck-chelsea-bill/fact-check-fabricated-chelsea-clinton-tweet-about-bill-gates-idUSL2N2NE2LK
# 839 https://www.reuters.com/article/us-jbs-climate/brazils-jbs-pledges-net-zero-greenhouse-emissions-by-2040-idUSKBN2BF2YL
# 840 https://www.reuters.com/article/us-usa-exxon-refinery-pollution-insight/three-exxon-refineries-top-the-list-of-u-s-polluters-idUSKCN2D911C
# 841 https://www.reuters.com/article/us-bank-of-america-results/bank-of-america-management-offers-optimistic-outlook-on-economy-reserves-idUSKBN2C219F
# 842 https://www.reuters.com/article/us-usa-diesel-diamondgreen/valero-joint-venture-to-become-top-u-s-renewable-diesel-producer-idUSKBN29Y30P
# 843 https://www.reuters.com/article/us-refinery-operations-marathon-galvesto/marathon-galveston-bay-refinery-in-texas-restarting-crude-unit-sources-idUSKBN2AN00N
# 844 https://www.reuters.com/article/us-siemens-gamesa-r-m-a-siemens-energy-s/siemens-energy-says-it-has-no-plans-for-full-siemens-gamesa-takeover-idUSKCN2CZ0P2
# 845 https://www.reuters.com/article/us-chip-shortage-foxconn/foxconn-chairman-says-expects-limited-impact-from-chip-shortage-on-clients-idUSKBN2AK067
# 846 https://www.reuters.com/article/us-global-oil-exxon-shell-wrap/investors-court-deliver-stark-warning-for-big-oil-on-climate-idUSKCN2D72V2
# 847 https://www.reuters.com/article/autos-tech-apple-hyundai-motor/s-koreas-regulator-to-probe-hyundai-motor-execs-for-alleged-insider-trading-report-idUSL4N2M51EA
# 848 https://www.reuters.com/article/jp-morgan-moves/jpmorgan-appoints-co-heads-of-consumer-community-bank-idUSL3N2N53OG
# 849 https://www.reuters.com/article/legal-us-shell-oil-alabama-refinery/vertex-energy-to-acquire-shells-mobile-alabama-refinery-idUSKCN2D825Q
# 850 https://www.reuters.com/article/us-global-forex/u-s-dollar-inches-up-pound-gains-after-uk-eu-strike-brexit-trade-deal-idUSKBN28Y04C
# 851 https://www.reuters.com/article/europe-stocks/european-stocks-rise-as-central-banks-pledge-easy-monetary-policy-idUSL3N2ND1U5
# 852 https://www.reuters.com/article/us-usa-biofuels-valero-specialreport/special-report-refiner-valeros-secret-campaign-against-u-s-biofuels-mandates-idUSKCN1B115D
# 853 https://www.reuters.com/article/exxon-mobil-agm-blackrock/exclusive-blackrock-backs-3-director-nominees-challenging-exxon-board-sources-idUSL2N2NC1KK
# 854 https://www.reuters.com/article/tadawul-ipo-int/saudi-tadawul-group-hires-jp-morgan-citi-ncb-capital-for-ipo-statement-idUSKBN2CF1ZD
# 855 https://www.reuters.com/article/factcheck-redcross-vaccinated-idUSL1N2MR1HU
# 856 https://www.reuters.com/article/us-ceraweek-wind-offshore/offshore-wind-industry-at-growth-inflection-point-bps-zero-carbon-energy-exec-says-idUSKBN2AW1VQ

# %% [markdown]
# ### 1.2.5. [5] Index statistics
#
# Load an index and print the statistics.

# %%
# load index, doc_lengths and doc_urls
with open(os.path.join('docs_collection', 'inverted_index.p'), 'rb') as fp:
    index = pickle.load(fp)
with open(os.path.join('docs_collection', 'doc_lengths.p'), 'rb') as fp:
    doc_lengths = pickle.load(fp)
with open(os.path.join('docs_collection', 'doc_urls.p'), 'rb') as fp:
    doc_urls = pickle.load(fp)
    
    
print('Total index length', len(index))
print('\nTop terms by number of documents they apperared in:')
sorted_by_n_docs = sorted(index.items(), key=lambda kv: (len(kv[1]), kv[0]), reverse=True)
print([(sorted_by_n_docs[i][0], len(sorted_by_n_docs[i][1])) for i in range(20)])
print('\nTop terms by overall frequency:')
sorted_by_freq = sorted(index.items(), key=lambda kv: (kv[1][0], kv[0]), reverse=True)
print([(sorted_by_freq[i][0], sorted_by_freq[i][1][0]) for i in range(20)])
# Out:
# Total index length 9917
#
# Top terms by number of documents they apperared in:
# [('min', 478), ('reuter', 477), ('trust', 472), ('standard', 472), ('thomson', 471), ('principl', 471), ('said', 401), ('edit', 399), ('have', 304), ('which', 298), ('not', 286), ('report', 281), ('more', 263), ('thi', 260), ('after', 257), ('also', 251), ('year', 241), ('compani', 231), ('but', 222), ('would', 220)]
#
# Top terms by overall frequency:
# [('said', 1857), ('reuter', 1743), ('have', 970), ('not', 883), ('report', 726), ('more', 614), ('which', 603), ('compani', 596), ('after', 581), ('they', 568), ('had', 559), ('year', 555), ('thi', 543), ('their', 529), ('been', 518), ('would', 514), ('or', 512), ('standard', 505), ('but', 505), ('trust', 492)]

# %% [markdown]
# ## 1.3. [15] Answering query
#
# Now, given that we already have built the inverted index, it's time to utilize it for answering user queries. In this class there are two methods you need to implement:
# - `boolean_retrieval`, the simplest form of document retrieval which returns a set of documents such that each one contains all query terms. Returns a set of document ids. Refer to *ch.1* of the book for details;
# - `okapi_scoring`, Okapi BM25 ranking function - assigns scores to documents in the collection that are relevant to the user query. Returns a dictionary of scores, `doc_id:score`. Read about it in [Wikipedia](https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function) and implement accordingly.
#
# Both methods accept `query` parameter in a form of a dictionary, `term:frequency`

# %%
from collections import Counter
import math

class QueryProcessing:
    
    @staticmethod
    def prepare_query(raw_query):
        prep = Preprocessor()
        # pre-process query the same way as documents
        query = prep.preprocess(raw_query)
        # count frequency
        count = Counter()
        for word in query:
            count[word] += 1
        return count
    
    @staticmethod
    def boolean_retrieval(query, index):
        retrieval = []
        # AND boolean retrieval
        for word in query:
            # [(doc_id, term_freq)]
            freqs = index[word][1:]
            if not retrieval:
                # i[0] - document id
                retrieval = [i[0] for i in freqs]
            else:
                # Intersection
                retrieval = [i[0] for i in freqs if i[0] in retrieval]
        return set(retrieval)

    @staticmethod
    def okapi_scoring(query, doc_lengths, index, k1=1.2, b=0.75):
        okapi = {}
        avg_len = 0
        N = len(doc_lengths)
        for i in doc_lengths.values():
            avg_len += i
        avg_len /= N
        for word in query:
            inv_ind = index[word]
            n_q = len(inv_ind[1:])
            IDF = math.log((N - n_q + 0.5) / (n_q + 0.5))
            for freq in inv_ind[1:]:
                okapi.setdefault(freq[0], 0)
                okapi[freq[0]] += IDF * freq[1] * (k1 + 1) \
                                / (freq[1] + k1 * (1 - b + b * doc_lengths[freq[0]] / avg_len))
        return okapi

# %% [markdown]
# ### 1.3.1. Tests

# %%
test_doc_lengths = {1: 20, 2: 15, 3: 10, 4:20, 5:30}
test_index = {'xx': [2, (1, 1), (2, 1)], 'yy': [2, (1, 1), (3, 1)], 'zz': [3, (2, 1), (4,2)]}


test_query1 = QueryProcessing.prepare_query('xx zz')
test_query2 = QueryProcessing.prepare_query('xx yy')

assert QueryProcessing.boolean_retrieval(test_query1, test_index) == {2}
assert QueryProcessing.boolean_retrieval(test_query2, test_index) == {1}
okapi_res = QueryProcessing.okapi_scoring(test_query2, test_doc_lengths, test_index)
assert all(k in okapi_res for k in (1, 2, 3))
assert not any(k in okapi_res for k in (4, 5))
assert okapi_res[1] > okapi_res[3] > okapi_res[2]

# %%
#TODO write a web-service that answers queries using inverted index

# %% [markdown]
# # 2. [55] Sorri not veri gud in inglish
#
# Have you ever googled someone's name without knowing exactly how it should be written? Were you ever reluctant to look up the correct spelling of a query you typed? Or just unable to type properly because of being in a rush? Modern search engines usually do a pretty good job in deciphering defective user input. In order to be able to do that, a good spell-checking mechanism should be incorporated into a search procedure. Today we will take one step further towards building a good search engine and work on tolerant retrieval with respect to user queries. We will consider two cases:
#
# 1. User knows that he doesn't know the correct spelling OR he wants to get the results that follow some known pattern, so he uses so called wildcards - queries like `retr*val`;
# 2. User doesn't know the correct spelling OR he doesn't care OR he's in a rush OR he expects his mistakes will be corrected OR your option, so he makes mistakes and we need to handle them using:
#
#     2.1. Simple spellchecker by Peter Norvig;
#
#     2.2. Phonetic correction by means of Soundex algorithm;
#
#     2.3. Trigrams with Jaccard coefficient.

# %% [markdown]
# ## 2.1. [20] Handling wildcards
#
# We will handle wildcard queries using k-grams. K-grams is a list of consecutive k chars in a string - i.e., for the word *'star'*, it will be '*\$st*', '*sta*', '*tar*', and '*ar$*', if we take k=3. Take a look at [book](https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf) *chapter 3.2.2* to understand how k-grams can help efficiently match a wildcard against dictionary words. Here we will only consider wildcards with star symbols (may be multiple).
#
# Notice that for building k-grams index, **we will need a vocabulary of original word forms** to compare words in user input to the vocabulary of "correct" words (think why inverted index which we built for stemmed words doesn't work here).
#
# You need to implement the following:
#
# - `build_inverted_index_orig_forms` - creates inverted index of original world forms from `facts` list, which is already given to you.
#     Output format: `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#
#
# - `build_k_gram_index` - creates k-gram index which maps every k-gram encountered in facts collection to a list of words containing this k-gram. Use the abovementioned inverted index of original words to construct this index.
#     Output format: `'k_gram': ['word1_with_k_gram', 'word2_with_k_gram', ...]`
#
#
# - `generate_wildcard_options` - produce a list of vocabulary words matching given wildcard by intersecting postings of k-grams present in the wildcard (refer to *ch 3.2.2*).
#
# - `search_wildcard` - return list of facts that contain the words matching a wildcard query.
#
#
# We will use the dataset with curious facts for testing.
#
# ### 2.1.1. Downloading the dataset

# %%
import urllib.request
data_url = "https://raw.githubusercontent.com/hsu-ai-course/hsu.ai/master/code/datasets/nlp/facts.txt"
local_filename, headers = urllib.request.urlretrieve(data_url)

facts = []
'''
with open(local_filename) as fp:
    for cnt, line in enumerate(fp):
        facts.append(line.strip('\n'))'''
# Correct facts (21-24 facts repeat)
with open("facts.txt", 'r') as fp:
    for cnt, line in enumerate(fp):
        facts.append(line.strip('\n'))
print(*facts[-5:], sep='\n')
# Out:
# 151. Women have twice as many pain receptors on their body than men. But a much higher pain tolerance.
# 152. There are more stars in space than there are grains of sand on every beach in the world.
# 153. For every human on Earth there are 1.6 million ants.
# 154. The total weight of all those ants, however, is about the same as all the humans.
# 155. On Jupiter and Saturn it rains diamonds.

# %% [markdown]
# ### 2.1.2. [20] Implementation of search

# %%
import re
from nltk import word_tokenize
from nltk.util import ngrams

def build_inverted_index_orig_forms(documents):
    inverted_index = {}
    for raw_doc in documents:
        # Split id of fact and its content
        doc = raw_doc.split(".")
        doc_id = int(doc[0])
        # Content
        doc_proc = word_tokenize(" ".join(doc[1:]).lower())
        # Copypaste from 1.2.2
        count = Counter()
        for word in doc_proc:
            count[word] += 1
        for word in count:
            if len(inverted_index.setdefault(word, [])) == 0:
                inverted_index.setdefault(word, []).append(count[word])
            else:
                inverted_index.setdefault(word, [])[0] +=count[word]
            inverted_index.setdefault(word, []).append((doc_id, count[word]))
    return inverted_index



def build_k_gram_index(inverted_index, k):
    k_gram_index = {}
    # For each word in vocab create a list on k-grams
    for word in inverted_index.keys():
        k_grams = ngrams("$" + word + "$", k)
        # Add 'word' to dict with key 'k_gram'
        for i in k_grams:
            k_gram = "".join(i)
            k_gram_index.setdefault(k_gram, []).append(word)
    return k_gram_index

# Divide wildcard by k-grams; for each k-gram return its words;
# make an intersection of words
def generate_wildcard_options(wildcard, k_gram_index, inverted_index, k=3):
    wildcard = "$" + wildcard + "$"
    patterns = wildcard.split("*")
    words = []
    # ['re', 'ed']
    for gram in patterns:
        K = len(gram)
        # Create another k_gram_index, if k in k_gram_index is not K
        if K != k:
            k_gram_index_ = build_k_gram_index(inverted_index, K)
        else:
            k_gram_index_ = k_gram_index
        voc_words = k_gram_index_[gram]
        if not words:
            words = voc_words
        else:
            # Intersection between words and the new list
            words = [i for i in voc_words if i in words]
    return words

# Get matching of wildcard; for each matching find documents where it occurs
def search_wildcard(wildcard, k_gram_index, index, docs):
    words = generate_wildcard_options(wildcard, k_gram_index, index)
    ids = []
    for word in words:
        docs_list = index[word][1:]
        for i in docs_list:
            ids.append(i[0])
    # docs start from 1
    return [docs[id-1] for id in ids]

# %% [markdown]
# ### 2.1.3. Tests

# %%
index_orig_forms = build_inverted_index_orig_forms(facts)
k_gram_index = build_k_gram_index(index_orig_forms, 3)
print(k_gram_index)
wildcard = "re*ed"

wildcard_options = generate_wildcard_options(wildcard, k_gram_index, index_orig_forms)
print(wildcard_options)
assert(len(wildcard_options) >= 3)

wildcard_results = search_wildcard(wildcard, k_gram_index, index_orig_forms, facts)
# some pretty printing
for r in wildcard_results:
    # highlight terms for visual evaluation
    for term in wildcard_options:
        r = re.sub(r'(' + term + ')', r'\033[1m\033[91m\1\033[0m', r, flags=re.I)
    print(r)

assert(len(wildcard_results) >=3)
# Out:
# {'$if': ['if'], 'if$': ['if'], '$yo': ['you', 'your', 'york', 'yourself'], 'you': ['you', 'your', 'yourself'], 'ou$': ['you'], '$so': ['somehow', 'southern', 'son', 'soda', 'soft-boiled', 'so', 'someone', 'sometimes', 'solar', 'some'], 'som': ['somehow', 'someone', 'sometimes', 'some'], 'ome': ['somehow', 'women', 'someone', 'sometimes', 'comes', 'homeless', 'become', 'some'], 'meh': ['somehow'], 'eho': ['somehow'], 'how': ['somehow', 'however'], 'ow$': ['somehow', 'snow', 'cow', 'follow', 'now', 'low'], '$fo': ['found', 'food', 'forelegs', 'for', 'foot', 'folded', 'fountain', 'follow', 'fourth', 'footprints', 'founders', 'four'], 'fou': ['found', 'fountain', 'fourth', 'founders', 'four'], 'oun': ['found', 'pounds', 'around', 'fountain', 'pronounce', 'pound', 'bloodhound', 'mountain', 'bounce', 'founders', 'amount', 'country'], 'und': ['found', 'under', 'pounds', 'around', 'underneath', 'pound', 'bloodhound', 'understanding', 'founders', 'sunday'], 'nd$': ['found', 'land', 'and', 'around', 'zealand', 'kind', 'finland', 'pound', 'bloodhound', 'second', 'tend', 'england', 'find', 'sand'], '$a$': ['a'], '$wa': ['way', 'waiting', 'was', 'watching', 'walks', 'wall', 'water', 'war', 'want', 'waterfall', 'watered', 'warriors', 'wasps'], 'way': ['way', 'away', 'always'], 'ay$': ['way', 'away', 'day', 'say', 'ebay', 'may', 'sunday', 'friday'], '$to': ['to', 'tongue', 'toothpaste', 'tolerance', 'toxins', 'total'], 'to$': ['to', 'into', 'kyoto', 'pluto'], '$ex': ['extract', 'executed', 'expected', 'execution', 'excite'], 'ext': ['extract', 'text'], 'xtr': ['extract'], 'tra': ['extract', 'travels', 'traveled', 'travel', 'train', 'attractive', 'translates', 'tracked', 'traffic', 'demonstrated', 'concentrate'], 'rac': ['extract', 'attractive', 'tracked'], 'act': ['extract', 'act', 'bacteria', 'attractive', 'actually'], 'ct$': ['extract', 'act', 'collect'], '$al': ['all', 'aliens', 'al', 'allergic', 'always', 'alcohol'], 'all': ['all', 'calls', '4-foot-tall', 'wall', 'physically', 'allergic', 'actually', 'eventually', 'waterfall', 'ten-gallon', 'gallon', 'originally', 'call', 'literally', 'tall', 'balloon', 'called', 'ball', 'falling', 'fall'], 'll$': ['all', 'still', 'will', 'bill', '4-foot-tall', 'wall', 'well', 'sell', 'waterfall', 'fill', 'call', 'kill', 'tall', 'ball', "'ll", 'fall'], '$of': ['of', 'often', 'off'], 'of$': ['of'], '$th': ['the', 'their', 'than', 'there', 'that', 'they', 'these', 'them', 'three', 'things', 'thigh', 'thought', 'themselves', 'this', 'thirsty', 'those'], 'the': ['the', 'their', 'there', 'southern', 'they', 'these', 'them', 'farther', 'father', 'other', 'others', 'breathe', 'leather', 'mathematical', 'themselves', 'another'], 'he$': ['the', 'he', 'breathe'], '$go': ['gold', 'gorilla', 'gorillas', 'got', 'good', 'go', 'goes', 'god', 'golden', 'google'], 'gol': ['gold', 'golden'], 'old': ['gold', 'oldest', 'old', 'folded', 'holds', 'hold', 'golden', 'hold-off', 'older', 'holding'], 'ld$': ['gold', 'would', 'child', 'world', 'old', 'could', 'donald', 'held', 'hold'], '$fr': ['from', 'frequent', 'france', 'free', 'fruit', 'frog', 'fried', 'french', 'friday'], 'fro': ['from', 'frog'], 'rom': ['from'], 'om$': ['from', 'venom'], '$bu': ['bubbling', 'buyers', 'burn', 'buchanan', 'buy', 'business', 'burns', 'but', 'burp', 'buyer', 'butterflies', 'building'], 'bub': ['bubbling'], 'ubb': ['bubbling', 'rubber'], 'bbl': ['bubbling'], 'bli': ['bubbling', 'public', 'republic', 'gambling'], 'lin': ['bubbling', 'slinky', 'telling', 'line', 'ceilings', 'outlines', 'willing', 'gambling', 'falling'], 'ing': ['bubbling', 'waiting', 'during', 'sleeping', 'watching', 'living', 'diving', 'hanging', 'hiding', 'single', 'lightning', 'coloring', 'chewing', 'moving', 'erupting', 'according', 'crying', 'banging', 'things', 'being', 'drying', 'meaning', 'telling', 'clothing', 'wedding', 'ring', 'growing', 'dying', 'winning', 'earrings', 'flying', 'swimming', 'evening', 'morning', 'fingerprints', 'using', 'raining', 'making', 'urinating',  ...
# ['red', 'recorded', 'received', 'reduced']
# 3. The average person spends 6 months of their lifetime waiting on a red light to turn green.
# 4. The largest recorded snowflake was in Keogh, MT during year 1887, and was 15 inches wide.
# 98. Blue-eyed people tend to have the highest tolerance of alcohol.
# 130. There are 60,000 miles of blood vessels in the human body.

# %% [markdown]
# ## 2.2. [35] Handling typos
#
# ### 2.2.1 Dataset
#
# Download github typo dataset from [here](https://github.com/mhagiwara/github-typo-corpus).
# Load it with this code:

# %%
# !pip install jsonlines

# %%
import jsonlines

dataset_file = "github-typo-corpus.v1.0.0.jsonl"

dataset = []
other_langs = set()

with jsonlines.open(dataset_file) as reader:
    for obj in reader:
        for edit in obj['edits']:
            if edit['src']['lang'] != 'eng':
                other_langs.add(edit['src']['lang'])
                continue

            if edit['is_typo']:
                src, tgt = edit['src']['text'], edit['tgt']['text']
                if src.lower() != tgt.lower():
                    dataset.append((edit['src']['text'], edit['tgt']['text']))
                
print(f"Dataset size = {len(dataset)}")
# Out:
# Dataset size = 245909

# %% [markdown]
# #### Explore sample typos
# Please, explore the dataset. You may see, that this is
# - mostly markdown
# - some common mistakes with do/does
# - some just refer to punctuation typos (which we do not consider)

# %%
for pair in dataset[1010:1020]:
    print(f"{pair[0]} => {pair[1]}")
# Out:
#         """Make am instance. =>         """Make an instance.
# * travis: test agains Node.js 11 => * travis: test against Node.js 11
# The parser receive a string and returns an array inside a user-provided  => The parser receives a string and returns an array inside a user-provided
# CSV data is send through the `write` function and the resulted data is obtained => CSV data is sent through the `write` function and the resulting data is obtained
# One useful function part of the Stream API is `pipe` to interact between  => One useful function of the Stream API is `pipe` to interact between
# source to a `stream.Writable` object destination. This example available as  => source to a `stream.Writable` object destination. This example is available as
# `node samples/pipe.js` read the file, parse its content and transform it. => `node samples/pipe.js` and reads the file, parses its content and transforms it.
# Most of the generator is imported from its parent project [CSV][csv] in a effort  => Most of the generator is imported from its parent project [CSV][csv] in an effort
# *   `quote`             Optionnal character surrounding a field, one character only, defaults to double quotes.    => *   `quote`             Optional character surrounding a field, one character only, defaults to double quotes.
# The parser receive a string and return an array inside a user-provided  => The parser receive a string and returns an array inside a user-provided

# %% [markdown]
# ### 2.2.2. [5] Build a dataset vocabulary
# We will need it for Norvig's spellchecker as well as for estimating overall correction quality. Consider only word-level. Be carefull, there is markdown (e.g. \`name\`. \[url\]\(http://url)) and comment symbols (\#, //, \*).

# %%
def sent_to_words(sent):
    # splits sentence to words, filtering out non-alphabetical terms
    words = nltk.word_tokenize(sent)    
    words_filtered = filter(lambda x: x.isalpha(), words)
    return words_filtered

# %%
vocabulary = Counter()
for pair in dataset:
    for word in sent_to_words(pair[1].lower()):
        vocabulary[word] += 1
len(vocabulary)
# Out:
# 63724

# %%
from itertools import islice
print(list(islice(vocabulary.items(), 10)))
# Out:
# [('function', 6193), ('de', 82), ('deutsch', 4), ('nocomments', 2), ('you', 42075), ('can', 26027), ('disable', 532), ('comments', 360), ('for', 44756), ('the', 207017)]

# %% [markdown]
# ### 2.2.3. [25] Implement context-independent spellcheker ##
#
# 0) Write code to compute editorial distance
#
# 1) [Norvig's corrector](https://norvig.com/spell-correct.html)
#
# 2) [Soundex](https://en.wikipedia.org/wiki/Soundex)
#
# 3) Trigrams with Jaccard coefficient.
#
# #### 2.2.3.0. [5] Editorial distance
#
# Frequently used distance measure between two character sequences. We will use this distance to sort Soundex search results.

# %%
def edit_dist(s1, s2) -> int:
    # Stolen from Wiki
    d = {}
    lenstr1 = len(s1)
    lenstr2 = len(s2)
    for i in range(-1,lenstr1+1):
        d[(i,-1)] = i+1
    for j in range(-1,lenstr2+1):
        d[(-1,j)] = j+1

    for i in range(lenstr1):
        for j in range(lenstr2):
            if s1[i] == s2[j]:
                cost = 0
            else:
                cost = 1
            d[(i,j)] = min(
                           d[(i-1,j)] + 1, # deletion
                           d[(i,j-1)] + 1, # insertion
                           d[(i-1,j-1)] + cost, # substitution
                          )
            if i and j and s1[i]==s2[j-1] and s1[i-1] == s2[j]:
                d[(i,j)] = min (d[(i,j)], d[i-2,j-2] + cost) # transposition

    return d[lenstr1-1,lenstr2-1]

# %%
# tests

assert edit_dist("korrectud", "corrected") == 2, "Edit distance is computed incorrectly"
assert edit_dist("soem", "some") == 1, "Edit distance is computed incorrectly"
assert edit_dist("one", "one") == 0, "Edit distance is computed incorrectly"

# %% [markdown]
# #### 2.2.3.1. [5] Norvig's spellchecker

# %%
# Stolen from Peter Norvig
def P(word, N=sum(vocabulary.values())):
    "Probability of `word`."
    return vocabulary[word] / N

def correction(word):
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words):
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in vocabulary)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

def fix_typo_norvig(word) -> str:
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

# %%
# tests

assert fix_typo_norvig("korrectud") == "corrected", "Norvig's correcter doesn't work"
assert fix_typo_norvig("speling") == "spelling", "Norvig's correcter doesn't work"

assert fix_typo_norvig("wort") == "work", "Norvig's correcter doesn't work"
assert fix_typo_norvig("mornin") == "morning", "Norvig's correcter doesn't work"
assert fix_typo_norvig("cofee") == "coffee", "Norvig's correcter doesn't work"

# %% [markdown]
# #### 2.2.3.2. [10] Soundex
#
# For cases when the exact spelling is unknown, phonetic algorithms such as Soundex can be very helpful - they allow user to type a word the way he thinks it should sound, and then suggest the corrrect version. Go through *chapter 3.4* to understand how Soundex algorithm works.

# %%
# letter -> number from soundex
def code_map(letter):
    if letter in ['b', 'f', 'p', 'v']:
        return '1'
    elif letter in ['c', 'g', 'j', 'k', 'q', 's', 'x', 'z']:
        return '2'
    elif letter in ['d', 't']:
        return '3'
    elif letter in ['l']:
        return '4'
    elif letter in ['m', 'n']:
        return '5'
    elif letter in ['r']:
        return '6'
    else:
        return '0'

def produce_soundex_code(word):
    code = ""
    for letter in word:
        code += code_map(letter)
    # Flag, if catch a pair
    pair = False
    hash_word = code[0]
    # Remove pairs
    for i in range(1, len(code)):
        # If there is a pair, drop the second letter
        if code[i] == code[i-1] and not pair:
            pair = True
        else:
            hash_word += code[i]
            pair = False
    # Replace the code of first letter by letter itself
    hash_word = word[0] + hash_word[1:]
    # Remove zeroes
    hash_word = hash_word.replace('0', '')
    # Add trailing zeroes, if needed
    while len(hash_word) < 4:
        hash_word += '0'
    return hash_word[:4]


def build_soundex_index(dictionary):
    soundex_index = {}
    for word in dictionary.keys():
        soundex_index.setdefault(produce_soundex_code(word), []).append(word)
    return soundex_index


def fix_typo_soundex(word, soundex_index) -> list:
    soundex_index.setdefault(produce_soundex_code(word), [''])
    # Sorting by distance between possible correction and word
    return sorted(soundex_index[produce_soundex_code(word)], key=lambda x: edit_dist(x, word))

# %%
# tests

soundex_index = build_soundex_index(vocabulary)
print(soundex_index)
code1 = produce_soundex_code("britney")
code2 = produce_soundex_code("breatany")
print(code1, code2)
assert code1 == code2
print(fix_typo_soundex("enouhg", soundex_index))
assert "enough" in fix_typo_soundex("enouhg", soundex_index), "Assert soundex failed"
# Out:
# {'f523': ['function', 'functions', 'functional', 'functor', 'functionality', 'fenced', 'finished', 'functionally', 'functionalities', 'fencedfeedbackpanel', 'functionpointerwithcontext', 'functioninfo', 'functionname', 'fnstring', 'functorial', 'functionnode', 'functionnality', 'functioning', 'finestra', 'functionalplus', 'funcdef', 'functionexpression', 'functiondeclaration', 'functionstmt', 'funcction', 'funktion', 'functionscript', 'functionalsourceset', 'functionevent', 'funciton', 'funciotn', 'functionalinterfaces', 'finishdynamicimport', 'functionreceivedarguments', 'functionalizing', 'functors', 'functionpass', 'functiontype', 'functons', 'funxtion', 'functionnal', 'functionbasedbushingforce', 'finest', 'functionfactory', 'functiondefinitionast', 'finishwitherror', 'functools', 'functionalty', 'functionnalities', 'functionalcollectiondata', 'functionaltabledata', 'functionalize'], 'd000': ['de', 'due', 'do', 'day', 'dd', 'd', 'dw', 'dt', 'dy', 'di', 'da', 'die', 'du', 'dao', 'dae', 'duo', 'deo', 'doe', 'doi', 'dto', 'ddau', 'dea', 'dh', 'daw', 'diy', 'dai', 'dyy', 'dti', 'dia', 'doh', 'dhi', 'dhh', 'duh', 'dtw', 'dhe', 'dew', 'douwe'], 'd320': ['deutsch', 'datejs', 'deduce', 'dates', 'detach', 'dots', 'dodge', 'duties', 'ditch', 'deaths', 'deeds', 'dados', 'dutch', 'dettach', 'detox', 'datas', 'dudes', 'dhts', 'dietze', 'dodds', 'dids'], 'n255': ['nocomments', 'ngoninit', 'nganimate', 'nickname', 'nicknames', 'nsmenufx', 'nsnumber', 'nicknamed', 'nocanon', 'nsmanagedobject'], 'y000': ['you', 'y', 'yeah', 'yahoo', 'yo', 'yea', 'yii', 'yaw', 'yay', 'yyyy', 'yy', 'yyww', 'yey', 'yi', 'yeh', 'yui', 'yyy', 'yihui'], 'c500': ['can', 'comma', 'chen', 'come', 'chain', 'cnn', 'came', 'cayenne', 'conway', 'cn', 'cni', 'cheney', 'com', 'conn', 'coin', 'comm', 'cchain', 'coma', 'china', 'chown', 'chan', 'cone', 'chinmay', 'cm', 'cemu', 'canoe', 'con', 'cgan', 'camo', 'cyan', 'ccm', 'cena', 'ccan', 'cgm', 'cmu', 'csum', 'cin', 'cson', 'chem', 'cim', 'cen', 'csom', 'cumo', 'cohen', 'côme', 'cgen', 'chm', 'cwm', 'cmn'], 'd214': ['disable', 'disabling', 'disabled', 'displays', 'display', 'disabilities', 'displayed', 'displaying', 'displayname', 'decoupled', 'disablewebinterface', 'decouple', 'displacements', 'diskbalancer', 'disables', 'displayjs', 'disabledpackages', 'displayable', 'decoupling', 'displying', 'displaystacktrace', 'displaymath', 'discipline', 'docblock', 'decouples', 'disableshowhiddenfilesfoldersdrives', 'displayport', 'disciplined', 'disablesorting', 'disability', 'displaced', 'displacy', 'displace', 'displacement', 'disciples', 'desplegables', 'docfields', 'disablebrowsererror', 'disableddays', 'disableinviewcontrollerclass', 'disabletoolbarinviewcontrollerclass', 'displayer', 'displayscale', 'docfile', 'disciplines', 'disablecache', 'displayimg', 'disabledinput', 'disablelayerhinting', 'disableautoupdate', 'disablelazyloading', 'displayobjects', 'displaytype', 'deisplays', 'disablehydration', 'displayobject', 'dasblog', 'displayanimagewithstyle', 'disablekeycompression', 'docplex', 'dogvalidatorsareproc', 'disabledigestupdates', 'disableinlineattachmentviewing', 'dispplays', 'disableinternalcommands', 'displayerrors', 'docblocks', 'disableredirecturltracking', 'disfluency', 'disabletouch', 'docbloc', 'displaytemplate', 'decibels', 'displayloadingindicator', 'disableable'], 'c553': ['comments', 'community', 'command', 'commented', 'commandline', 'comment', 'commenting', 'commands', 'communities', 'commandgroup', 'commonmodule', 'commanddescription', 'commentstart', 'commandlineparser', 'commandresult', 'commandlauncher', 'commandreporter', 'commander', 'commandbus', 'commandhandlerinterceptor', 'commandexecutor', 'comunity', 'chomeintro', 'commentframe', 'commondir', 'commandcollection', 'commandtask', 'commandretry', 'camunda', 'commandfor', 'commenters', 'communityforumtooltip', 'commanded', 'commandcenter', 'commandcooldown', 'commandlogging', 'commandmessagelifetime', 'cements', 'commandresponse', 'commandname',  ...
# b635 b635
# ['enough', 'ensue', 'eng', 'enjoy', 'emoji', 'enqueue', 'ens', 'enc', 'emojii', 'enki', 'enso', 'enzo', 'enwiki', 'emesh', 'emg', 'emacs', 'emc', 'emas', 'euank', 'emq', 'enmasse', 'emac', 'emmc', 'emgo']

# %% [markdown]
# #### 2.2.3.3. [5] Trigrams with Jaccard coefficient

# %%
def IoU(A, B):
    return len([i for i in A if i in B]) / len(list(set(A) | set(B)))

def fix_typo_kgram(word, k_gram_index, k =3) -> list:
    k_grams = ngrams("$" + word + "$", k)
    word_sets = []
    for i in k_grams:
        # If there is no grams (to avoid throws)
        k_gram_index.setdefault(''.join(i), [''])
        word_sets.append(k_gram_index[''.join(i)])
    matches = []
    for i in range(len(word_sets)):
        for j in range(i+1, len(word_sets)):
            if IoU(word_sets[i], word_sets[j]) > 0.0:
                matches += [i for i in word_sets[i] if i in word_sets[j]]
    matches = set(matches)
    return sorted(matches, key=lambda x: edit_dist(x, word)) or ['']

# %%
# tests

k_gram_index_github = build_k_gram_index(vocabulary, 3)
print(fix_typo_kgram("enouh", k_gram_index_github)[:20])
assert "enough" in fix_typo_kgram("enouh", k_gram_index_github), "Assert k-gram failed"
# Out:
# ['enough', 'eno', 'enought', 'enoent', 'enosys', 'enomem', 'enospc', 'renounce', 'enormous', 'exogenous', 'enormously', 'endogenous', 'homogenous', 'hetrogenous', 'heterogenous', 'enodeuricomponent', 'ensuretablenotexists', 'testnotenoughqueryargs', 'entitytypenotfoundexception']

# %% [markdown]
# ## 2.2.4. [5] Estimate quality

# %%
norvig, soundex, kgram = 0, 0, 0
limit = 10000
counter = limit
for i, (src, target) in enumerate(dataset):
    if i == limit:
        break
    words = sent_to_words(src.lower())
    # word suspected for typos
    sn, ss, sk = src.lower(), src.lower(), src.lower()
    for word in words:
        if word not in vocabulary and word.isalpha():
            # top-1 accuracy
            wn, ws, wk = fix_typo_norvig(word), \
                         fix_typo_soundex(word, soundex_index)[0], \
                         fix_typo_kgram(word, k_gram_index_github)[0]
            sn = sn.replace(word, wn)
            ss = ss.replace(word, ws)
            sk = sk.replace(word, wk)
    norvig += int(sn == target.lower())
    soundex += int(ss == target.lower())
    kgram += int(sk == target.lower())

print(f"Norvig accuracy ({norvig}) = {norvig / limit}")
print(f"Soundex accuracy ({soundex}) = {soundex / limit}")
print(f"k-gram accuracy ({kgram}) = {kgram / limit}")
# Out:
# Norvig accuracy (2430) = 0.243
# Soundex accuracy (1845) = 0.1845
# k-gram accuracy (1952) = 0.1952
